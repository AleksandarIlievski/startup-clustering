# %% [markdown]
# # Exploration and Preprocessing

# %%
# Import relevant packages
import pandas as pd
import numpy as np
import os
import json

# %% [markdown]
# ## Data Loading

# %%
        
# Read JSON file into a dictionary
with open('../../data/raw/startup_list_0_5000_without_cookie.json', 'r') as file:
    data = json.load(file)

# Create a list of dictionaries to hold the row data
rows = []
for key, value in data.items():
    row = value.copy()
    row['name'] = value.pop('name')
    rows.append(row)


# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(rows)
df
# Out:
#                         name  original_idx                 website_url  \
# 0                    itravel             0     https://www.itravel.de/
# 1                    kunveno             2          https://kunveno.de
# 2     t2k: Text to Knowledge             3   https://text2knowledge.de
# 3                     Scopas             4      https://www.scopas.io/
# 4                studymaniac             5      https://studymaniac.de
# ...                      ...           ...                         ...
# 3284                  Coleap          4994         https://coleap.com/
# 3285       Trade Machines FI          4995    http://trademachines.com
# 3286                  Yasoon          4996          http://yasoon.com/
# 3287              Phoneboost          4997  https://www.phoneboost.de/
# 3288             Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text
# 0     itravel Telefonische Beratung +49 221 8282 888...
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...
# 2                                 Text 2 Knowledge You.
# 3     ScopasWe're working on something new.Check it ...
# 4     Studymaniac - erfolgreich Studieren Open main ...
# ...                                                 ...
# 3284  Coleap Transform your content into incomeTurn ...
# 3285  ▷ All used industrial equipment online on Trad...
# 3286  Home - yasoon Patrick Partner Manager Get in t...
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...
# 3288  Gaius - Dein Personal Legal Assistant Homepage...
#
# [3289 rows x 4 columns]

# %% [markdown]
# ## Cleaning the Html as preprocessing step for text translation

# %%
import re

#functions to clean Html as first step of the preprocessing
def cleanHtml(sentence):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', str(sentence))
    cleantext = cleantext.replace("\n"," ")
    cleantext = cleantext.replace("√ú","Ü")
    cleantext = cleantext.replace("√ü","ß")
    cleantext = cleantext.replace("√∂", "ö")
    cleantext = cleantext.replace("√º", "ü")
    cleantext = cleantext.replace("√§", "ä")
    cleantext = cleantext.replace("&", "and")
    cleantext = cleantext.replace("‚Äú", " ")
    cleantext = cleantext.replace("¬†", " ")
    return cleantext

df['website_text'] = df['website_text'].apply(cleanHtml)
df
# Out:
#                         name  original_idx                 website_url  \
# 0                    itravel             0     https://www.itravel.de/
# 1                    kunveno             2          https://kunveno.de
# 2     t2k: Text to Knowledge             3   https://text2knowledge.de
# 3                     Scopas             4      https://www.scopas.io/
# 4                studymaniac             5      https://studymaniac.de
# ...                      ...           ...                         ...
# 3284                  Coleap          4994         https://coleap.com/
# 3285       Trade Machines FI          4995    http://trademachines.com
# 3286                  Yasoon          4996          http://yasoon.com/
# 3287              Phoneboost          4997  https://www.phoneboost.de/
# 3288             Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text
# 0     itravel Telefonische Beratung +49 221 8282 888...
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...
# 2                                 Text 2 Knowledge You.
# 3     ScopasWe're working on something new.Check it ...
# 4     Studymaniac - erfolgreich Studieren Open main ...
# ...                                                 ...
# 3284  Coleap Transform your content into incomeTurn ...
# 3285  ▷ All used industrial equipment online on Trad...
# 3286  Home - yasoon Patrick Partner Manager Get in t...
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...
# 3288  Gaius - Dein Personal Legal Assistant Homepage...
#
# [3289 rows x 4 columns]

# %%
#test result and store the result in another dataframe 
df_result = df.copy(deep=True)
df_result
# Out:
#                         name  original_idx                 website_url  \
# 0                    itravel             0     https://www.itravel.de/
# 1                    kunveno             2          https://kunveno.de
# 2     t2k: Text to Knowledge             3   https://text2knowledge.de
# 3                     Scopas             4      https://www.scopas.io/
# 4                studymaniac             5      https://studymaniac.de
# ...                      ...           ...                         ...
# 3284                  Coleap          4994         https://coleap.com/
# 3285       Trade Machines FI          4995    http://trademachines.com
# 3286                  Yasoon          4996          http://yasoon.com/
# 3287              Phoneboost          4997  https://www.phoneboost.de/
# 3288             Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text
# 0     itravel Telefonische Beratung +49 221 8282 888...
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...
# 2                                 Text 2 Knowledge You.
# 3     ScopasWe're working on something new.Check it ...
# 4     Studymaniac - erfolgreich Studieren Open main ...
# ...                                                 ...
# 3284  Coleap Transform your content into incomeTurn ...
# 3285  ▷ All used industrial equipment online on Trad...
# 3286  Home - yasoon Patrick Partner Manager Get in t...
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...
# 3288  Gaius - Dein Personal Legal Assistant Homepage...
#
# [3289 rows x 4 columns]

# %%
#load the result from steps before
df = df_result.copy(deep=True)
df
# Out:
#                         name  original_idx                 website_url  \
# 0                    itravel             0     https://www.itravel.de/
# 1                    kunveno             2          https://kunveno.de
# 2     t2k: Text to Knowledge             3   https://text2knowledge.de
# 3                     Scopas             4      https://www.scopas.io/
# 4                studymaniac             5      https://studymaniac.de
# ...                      ...           ...                         ...
# 3284                  Coleap          4994         https://coleap.com/
# 3285       Trade Machines FI          4995    http://trademachines.com
# 3286                  Yasoon          4996          http://yasoon.com/
# 3287              Phoneboost          4997  https://www.phoneboost.de/
# 3288             Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text
# 0     itravel Telefonische Beratung +49 221 8282 888...
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...
# 2                                 Text 2 Knowledge You.
# 3     ScopasWe're working on something new.Check it ...
# 4     Studymaniac - erfolgreich Studieren Open main ...
# ...                                                 ...
# 3284  Coleap Transform your content into incomeTurn ...
# 3285  ▷ All used industrial equipment online on Trad...
# 3286  Home - yasoon Patrick Partner Manager Get in t...
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...
# 3288  Gaius - Dein Personal Legal Assistant Homepage...
#
# [3289 rows x 4 columns]

# %% [markdown]
# # Text translation

# %%
from langdetect import detect

#count number of texts in different langauges 
lang_counters = {}
deleted_row_counter = 0
for index, row in df.iterrows():
    if len(row['website_text']) >= 24 and row['website_text'] != 'Error: Failed to get response':
        language = detect(row['website_text'])
        df.at[index, 'language'] = language
        if language in lang_counters:
            lang_counters[language] += 1
        else:
            lang_counters[language] = 1
    
    if len(row['website_text']) == 0 or row['website_text'] == 'Error: Failed to get response':
        print(f"\033[33m Attention: \033[0m At index {index} no text is found and will be deleted.")
        deleted_row_counter += 1
        df = df.drop(index)
    if len(row['website_text']) <= 24 and len(row['website_text']) != 0:
        print(f"\033[33m Attention: \033[0m At index {index} text is too short and will be deleted: {row['website_text']}")
        deleted_row_counter += 1
        #delete row from Dataframe with empty text
        df = df.drop(index)
    if 'Seite wurde nicht gefunden' in row['website_text']:
        print(f"\033[33m Attention: \033[0m At index {index} website could not be scraped and will be deleted: {row['website_text']}")
        deleted_row_counter += 1
        # Lösche die Zeilen, die den Text enthalten
        df = df.drop(index)
    if 'Site is undergoing maintenance' in row['website_text']:
        print(f"\033[33m Attention: \033[0m At index {index} website is under maintanenance and will be deleted: {row['website_text']}")
        deleted_row_counter += 1
        # Lösche die Zeilen, die den Text enthalten
        df = df.drop(index)
        
print(f"Numbers of texts in different languages: {lang_counters}")
print(f"Number of deleted rows: {deleted_row_counter}")
# Out:
#  Attention:  At index 2 text is too short and will be deleted: Text 2 Knowledge You.
#  Attention:  At index 5 text is too short and will be deleted: Homepage - Numaferm
#  Attention:  At index 20 text is too short and will be deleted: BidX Tool
#  Attention:  At index 22 text is too short and will be deleted: Error: 503
#  Attention:  At index 67 text is too short and will be deleted: Field 33
#  Attention:  At index 83 text is too short and will be deleted: Error: 403
#  Attention:  At index 97 no text is found and will be deleted.
#  Attention:  At index 108 no text is found and will be deleted.
#  Attention:  At index 116 text is too short and will be deleted: www.lieferando.de
#  Attention:  At index 120 website could not be scraped and will be deleted: Seite wurde nicht gefunden. • Die LOYAL App Search for: 404 Error 404 Not Found Oops! That page can’t be found. It looks like nothing was found at this location. Search for: Teile mit deinen Freunden!Navigationsmenü Für Händler Copyright UMT AG 2019 © All rights reserved. | Corporate Key by
#  Attention:  At index 121 text is too short and will be deleted: Error: 404
#  Attention:  At index 139 text is too short and will be deleted: andCharge
#  Attention:  At index 161 no text is found and will be deleted.
#  Attention:  At index 180 text is too short and will be deleted: Leeway
#  Attention:  At index 192 text is too short and will be deleted: KOSTEDDE
#  Attention:  At index 209 no text is found and will be deleted.
#  Attention:  At index 214 no text is found and will be deleted.
#  Attention:  At index 218 text is too short and will be deleted: unzer
#  Attention:  At index 238 no text is found and will be deleted.
#  Attention:  At index 271 text is too short and will be deleted: Home • StargazrSorry!.
#  Attention:  At index 286 text is too short and will be deleted:
#  Attention:  At index 303 text is too short and will be deleted: Dashboard — Gitpod
#  Attention:  At index 321 text is too short and will be deleted: STARTSEITE - Rekonmed
#  Attention:  At index 339 text is too short and will be deleted: majestic® Journal
#  Attention:  At index 357 text is too short and will be deleted: Error: 404
#  Attention:  At index 362 text is too short and will be deleted: Cloud54 GmbH
#  Attention:  At index 378 text is too short and will be deleted: Error: 404
#  Attention:  At index 382 no text is found and will be deleted.
#  Attention:  At index 383 text is too short and will be deleted: Error: 500
#  Attention:  At index 397 text is too short and will be deleted: Error: 403
#  Attention:  At index 434 no text is found and will be deleted.
#  Attention:  At index 439 text is too short and will be deleted: Home | Frauwertvoll
#  Attention:  At index 454 no text is found and will be deleted.
#  Attention:  At index 455 no text is found and will be deleted.
#  Attention:  At index 456 text is too short and will be deleted: nea new reality
#  Attention:  At index 457 text is too short and will be deleted: CryptoMotors.
#  Attention:  At index 458 text is too short and will be deleted: Error: 404
#  Attention:  At index 463 no text is found and will be deleted.
#  Attention:  At index 476 text is too short and will be deleted: MedLink
#  Attention:  At index 490 website is under maintanenance and will be deleted: Site is undergoing maintenance Doctorsgate Der Wartungsmodus ist eingeschaltetSite will be available soon. Thank you for your patience! © Doctorsgate 2023 Benutzeranmeldung
#  Attention:  At index 492 text is too short and will be deleted: Startseite — MedBill
#  Attention:  At index 514 text is too short and will be deleted: CodeControl
#  Attention:  At index 516 text is too short and will be deleted: Error: 403
#  Attention:  At index 520 text is too short and will be deleted: Pentracor
#  Attention:  At index 522 text is too short and will be deleted: Home - de.consilio.com
#  Attention:  At index 525 text is too short and will be deleted: Error: 526
#  Attention:  At index 538 text is too short and will be deleted: Error: 404
#  Attention:  At index 556 no text is found and will be deleted.
#  Attention:  At index 561 no text is found and will be deleted.
#  Attention:  At index 564 text is too short and will be deleted: fgi DigitalSolutions
#  Attention:  At index 569 text is too short and will be deleted: Error: 404
#  Attention:  At index 593 no text is found and will be deleted.
#  Attention:  At index 597 text is too short and will be deleted: Error: 403
#  Attention:  At index 599 text is too short and will be deleted: Hinterland
#  Attention:  At index 601 no text is found and will be deleted.
#  Attention:  At index 613 text is too short and will be deleted: Fraugster.
#  Attention:  At index 614 no text is found and will be deleted.
#  Attention:  At index 625 no text is found and will be deleted.
#  Attention:  At index 632 no text is found and will be deleted.
#  Attention:  At index 640 text is too short and will be deleted: Startseite - Lynatox
#  Attention:  At index 649 website is under maintanenance and will be deleted: Site is undergoing maintenance FakeScoutsMaintenance mode is onSite will be available soon. Thank you for your patience! © FakeScouts 2021 User Login
#  Attention:  At index 656 text is too short and will be deleted: Error: 403
#  Attention:  At index 664 text is too short and will be deleted: GreenHomeNow
#  Attention:  At index 677 no text is found and will be deleted.
#  Attention:  At index 687 text is too short and will be deleted: Startseite - readyplace
#  Attention:  At index 688 no text is found and will be deleted.
#  Attention:  At index 711 text is too short and will be deleted: Home - t’works
#  Attention:  At index 719 text is too short and will be deleted: Home - Open Bank Project
#  Attention:  At index 734 no text is found and will be deleted.
#  Attention:  At index 751 no text is found and will be deleted.
#  Attention:  At index 806 no text is found and will be deleted.
#  Attention:  At index 813 no text is found and will be deleted.
#  Attention:  At index 818 text is too short and will be deleted: Error: 403
#  Attention:  At index 830 text is too short and will be deleted: Walberg Urban Electrics
#  Attention:  At index 832 text is too short and will be deleted: Error: 503
#  Attention:  At index 854 no text is found and will be deleted.
#  Attention:  At index 877 text is too short and will be deleted: Error: 404
#  Attention:  At index 878 text is too short and will be deleted: Error: 404
#  Attention:  At index 885 text is too short and will be deleted: Commonplace Robotics
#  Attention:  At index 892 text is too short and will be deleted: Quipleon
#  Attention:  At index 905 text is too short and will be deleted: Home-of-Lola - LoLaLabs
#  Attention:  At index 908 text is too short and will be deleted: Gunzilla Games
#  Attention:  At index 914 text is too short and will be deleted: Startseite - Auratikum
#  Attention:  At index 924 no text is found and will be deleted.
#  Attention:  At index 932 no text is found and will be deleted.
#  Attention:  At index 937 text is too short and will be deleted: GRID
#  Attention:  At index 953 no text is found and will be deleted.
#  Attention:  At index 956 no text is found and will be deleted.
#  Attention:  At index 957 text is too short and will be deleted: Error: 503
#  Attention:  At index 968 no text is found and will be deleted.
#  Attention:  At index 973 text is too short and will be deleted: Grossjungig
#  Attention:  At index 976 text is too short and will be deleted: Error: 403
#  Attention:  At index 979 no text is found and will be deleted.
#  Attention:  At index 982 no text is found and will be deleted.
#  Attention:  At index 984 text is too short and will be deleted: chariteam
#  Attention:  At index 995 text is too short and will be deleted: Home - Wahtari
#  Attention:  At index 1003 text is too short and will be deleted: Error: 403
#  Attention:  At index 1020 no text is found and will be deleted.
#  Attention:  At index 1021 text is too short and will be deleted: unzer
#  Attention:  At index 1026 text is too short and will be deleted: Error: 403
#  Attention:  At index 1038 no text is found and will be deleted.
#  Attention:  At index 1062 no text is found and will be deleted.
#  Attention:  At index 1069 text is too short and will be deleted: Innkeepr
#  Attention:  At index 1093 website could not be scraped and will be deleted: Seite wurde nicht gefunden. - Syngredient Oops, this Page could not be found. / Error 404 404 Not Found.
#  Attention:  At index 1103 text is too short and will be deleted: Error: 403
#  Attention:  At index 1111 no text is found and will be deleted.
#  Attention:  At index 1115 no text is found and will be deleted.
#  Attention:  At index 1124 no text is found and will be deleted.
#  Attention:  At index 1132 no text is found and will be deleted.
#  Attention:  At index 1142 text is too short and will be deleted: Error: 404
#  Attention:  At index 1157 text is too short and will be deleted: CFTools Cloud.
#  Attention:  At index 1172 no text is found and will be deleted.
#  Attention:  At index 1198 text is too short and will be deleted: Home - Pactum Securities
#  Attention:  At index 1200 no text is found and will be deleted.
#  Attention:  At index 1231 text is too short and will be deleted: SideGIG
#  Attention:  At index 1235 text is too short and will be deleted: Error: 404
#  Attention:  At index 1257 text is too short and will be deleted: Startseite - Dogo App
#  Attention:  At index 1267 no text is found and will be deleted.
#  Attention:  At index 1272 no text is found and will be deleted.
#  Attention:  At index 1278 no text is found and will be deleted.
#  Attention:  At index 1303 no text is found and will be deleted.
#  Attention:  At index 1317 text is too short and will be deleted: preML
#  Attention:  At index 1357 text is too short and will be deleted:  .
#  Attention:  At index 1358 no text is found and will be deleted.
#  Attention:  At index 1376 text is too short and will be deleted: Error: 500
#  Attention:  At index 1390 text is too short and will be deleted: Vacation Office -
#  Attention:  At index 1392 text is too short and will be deleted: ChargeX Deutschland
#  Attention:  At index 1399 no text is found and will be deleted.
#  Attention:  At index 1411 text is too short and will be deleted: smallstack GmbH
#  Attention:  At index 1414 text is too short and will be deleted: Home - TruPhysics
#  Attention:  At index 1422 text is too short and will be deleted: RideBee
#  Attention:  At index 1429 text is too short and will be deleted: Error: 404
#  Attention:  At index 1435 text is too short and will be deleted: TrustBills
#  Attention:  At index 1446 text is too short and will be deleted: MiuVi .
#  Attention:  At index 1452 text is too short and will be deleted: Error: 404
#  Attention:  At index 1465 text is too short and will be deleted: Home - Tweakstreet
#  Attention:  At index 1471 no text is found and will be deleted.
#  Attention:  At index 1477 no text is found and will be deleted.
#  Attention:  At index 1502 no text is found and will be deleted.
#  Attention:  At index 1508 no text is found and will be deleted.
#  Attention:  At index 1526 text is too short and will be deleted: Error: 500
#  Attention:  At index 1552 text is too short and will be deleted: Error: 423
#  Attention:  At index 1572 text is too short and will be deleted: Palturai Home - Palturai
#  Attention:  At index 1624 no text is found and will be deleted.
#  Attention:  At index 1639 text is too short and will be deleted: LootBoy
#  Attention:  At index 1647 no text is found and will be deleted.
#  Attention:  At index 1655 text is too short and will be deleted: Error: 404
#  Attention:  At index 1661 no text is found and will be deleted.
#  Attention:  At index 1664 text is too short and will be deleted: Kemialyitcs
#  Attention:  At index 1676 text is too short and will be deleted: Actaria
#  Attention:  At index 1683 text is too short and will be deleted: Fleetspark .
#  Attention:  At index 1704 text is too short and will be deleted: Error: 404
#  Attention:  At index 1741 text is too short and will be deleted: Home - ALVE
#  Attention:  At index 1742 text is too short and will be deleted: Error: 404
#  Attention:  At index 1744 no text is found and will be deleted.
#  Attention:  At index 1760 text is too short and will be deleted: Error: 404
#  Attention:  At index 1767 text is too short and will be deleted: Error: 500
#  Attention:  At index 1803 no text is found and will be deleted.
#  Attention:  At index 1807 text is too short and will be deleted: Shoop
#  Attention:  At index 1813 no text is found and will be deleted.
#  Attention:  At index 1816 text is too short and will be deleted: LootBoy
#  Attention:  At index 1826 text is too short and will be deleted: Error: 503
#  Attention:  At index 1836 text is too short and will be deleted: global tactics
#  Attention:  At index 1839 no text is found and will be deleted.
#  Attention:  At index 1847 text is too short and will be deleted: Holocafe
#  Attention:  At index 1849 text is too short and will be deleted: Clappline - clappline
#  Attention:  At index 1860 no text is found and will be deleted.
#  Attention:  At index 1862 text is too short and will be deleted: Error: 404
#  Attention:  At index 1874 text is too short and will be deleted: UX3D
#  Attention:  At index 1881 no text is found and will be deleted.
#  Attention:  At index 1922 text is too short and will be deleted: Lindis Blood Care
#  Attention:  At index 1934 text is too short and will be deleted: HOME » RFID
#  Attention:  At index 1937 no text is found and will be deleted.
#  Attention:  At index 1944 text is too short and will be deleted: OCEANERGY
#  Attention:  At index 1945 no text is found and will be deleted.
#  Attention:  At index 1961 text is too short and will be deleted: Error: 402
#  Attention:  At index 1963 no text is found and will be deleted.
#  Attention:  At index 1964 text is too short and will be deleted: Bitahoy .
#  Attention:  At index 1977 text is too short and will be deleted: exclamo .
#  Attention:  At index 1984 text is too short and will be deleted: LocaVent.
#  Attention:  At index 1987 text is too short and will be deleted: FIRMDER .
#  Attention:  At index 1994 text is too short and will be deleted: Error: 404
#  Attention:  At index 1999 text is too short and will be deleted: Error: 404
#  Attention:  At index 2008 no text is found and will be deleted.
#  Attention:  At index 2031 text is too short and will be deleted: Home - Medikura
#  Attention:  At index 2048 text is too short and will be deleted: Error: 404
#  Attention:  At index 2052 text is too short and will be deleted: Error: 403
#  Attention:  At index 2110 no text is found and will be deleted.
#  Attention:  At index 2113 no text is found and will be deleted.
#  Attention:  At index 2157 text is too short and will be deleted: Error: 404
#  Attention:  At index 2163 text is too short and will be deleted: Synsor.ai
#  Attention:  At index 2198 no text is found and will be deleted.
#  Attention:  At index 2199 text is too short and will be deleted: Home - Switplus
#  Attention:  At index 2224 text is too short and will be deleted: Error: 404
#  Attention:  At index 2249 text is too short and will be deleted: Error: 404
#  Attention:  At index 2251 no text is found and will be deleted.
#  Attention:  At index 2256 text is too short and will be deleted: Cultured Code
#  Attention:  At index 2265 text is too short and will be deleted: maracuja .
#  Attention:  At index 2277 no text is found and will be deleted.
#  Attention:  At index 2306 text is too short and will be deleted: zvarm
#  Attention:  At index 2313 text is too short and will be deleted: LegalHero
#  Attention:  At index 2354 text is too short and will be deleted: Error: 404
#  Attention:  At index 2373 no text is found and will be deleted.
#  Attention:  At index 2379 no text is found and will be deleted.
#  Attention:  At index 2381 text is too short and will be deleted: Error: 402
#  Attention:  At index 2388 no text is found and will be deleted.
#  Attention:  At index 2481 no text is found and will be deleted.
#  Attention:  At index 2488 text is too short and will be deleted: Home - Curvesys
#  Attention:  At index 2510 text is too short and will be deleted: TrustBills
#  Attention:  At index 2516 no text is found and will be deleted.
#  Attention:  At index 2524 text is too short and will be deleted: xymatic
#  Attention:  At index 2538 text is too short and will be deleted: LEMONSGATE
#  Attention:  At index 2555 no text is found and will be deleted.
#  Attention:  At index 2558 text is too short and will be deleted: Error: 404
#  Attention:  At index 2602 no text is found and will be deleted.
#  Attention:  At index 2625 no text is found and will be deleted.
#  Attention:  At index 2630 text is too short and will be deleted: Startseite - songquito
#  Attention:  At index 2646 no text is found and will be deleted.
#  Attention:  At index 2648 text is too short and will be deleted: WirHelfen
#  Attention:  At index 2657 no text is found and will be deleted.
#  Attention:  At index 2702 text is too short and will be deleted: Error: 404
#  Attention:  At index 2725 text is too short and will be deleted: FRC Digital Plattform
#  Attention:  At index 2749 no text is found and will be deleted.
#  Attention:  At index 2753 text is too short and will be deleted: Startseite - Evalea
#  Attention:  At index 2771 text is too short and will be deleted: Hyrd
#  Attention:  At index 2774 text is too short and will be deleted: Error: 500
#  Attention:  At index 2788 text is too short and will be deleted: iAutoFinance
#  Attention:  At index 2815 website is under maintanenance and will be deleted: Site is undergoing maintenance Monetic AG Maintenance mode is onSite will be available soon. Thank you for your patience! © Monetic AG 2023 User Login
#  Attention:  At index 2817 text is too short and will be deleted: Finqube .
#  Attention:  At index 2827 text is too short and will be deleted: Facts for Friends
#  Attention:  At index 2836 text is too short and will be deleted: FIWHA Solutions GmbH
#  Attention:  At index 2876 text is too short and will be deleted: StackPath de.gamigo.com
#  Attention:  At index 2887 no text is found and will be deleted.
#  Attention:  At index 2890 no text is found and will be deleted.
#  Attention:  At index 2891 no text is found and will be deleted.
#  Attention:  At index 2907 no text is found and will be deleted.
#  Attention:  At index 2909 text is too short and will be deleted: Error: 404
#  Attention:  At index 2935 text is too short and will be deleted: Livorit website .
#  Attention:  At index 2942 no text is found and will be deleted.
#  Attention:  At index 2949 text is too short and will be deleted: Error: 404
#  Attention:  At index 2956 text is too short and will be deleted: Error: 404
#  Attention:  At index 3003 text is too short and will be deleted: PurpleHome
#  Attention:  At index 3007 no text is found and will be deleted.
#  Attention:  At index 3010 no text is found and will be deleted.
#  Attention:  At index 3024 no text is found and will be deleted.
#  Attention:  At index 3066 no text is found and will be deleted.
#  Attention:  At index 3068 no text is found and will be deleted.
#  Attention:  At index 3088 text is too short and will be deleted: Home | CASCAT
#  Attention:  At index 3095 no text is found and will be deleted.
#  Attention:  At index 3096 text is too short and will be deleted: Conrati .
#  Attention:  At index 3098 no text is found and will be deleted.
#  Attention:  At index 3107 no text is found and will be deleted.
#  Attention:  At index 3112 text is too short and will be deleted: Campanda
#  Attention:  At index 3132 no text is found and will be deleted.
#  Attention:  At index 3157 text is too short and will be deleted: Home - Xylene
#  Attention:  At index 3164 no text is found and will be deleted.
#  Attention:  At index 3166 no text is found and will be deleted.
#  Attention:  At index 3171 no text is found and will be deleted.
#  Attention:  At index 3180 no text is found and will be deleted.
#  Attention:  At index 3184 text is too short and will be deleted: yourgix .
#  Attention:  At index 3187 text is too short and will be deleted: Welcome | Grunenthal
#  Attention:  At index 3199 text is too short and will be deleted: orgos.io
#  Attention:  At index 3201 text is too short and will be deleted: Gazindo .
#  Attention:  At index 3203 text is too short and will be deleted: Vinnova GmbH
#  Attention:  At index 3204 no text is found and will be deleted.
#  Attention:  At index 3210 text is too short and will be deleted: Error: 403
#  Attention:  At index 3225 text is too short and will be deleted: mocica.de
#  Attention:  At index 3262 no text is found and will be deleted.
# Numbers of texts in different languages: {'de': 1803, 'en': 1187, 'nl': 14, 'et': 1, 'es': 2, 'hr': 1, 'ro': 3, 'pl': 1, 'no': 3, 'da': 2, 'ca': 1, 'fr': 2, 'af': 2, 'ru': 1, 'bn': 1, 'it': 1, 'tr': 1, 'pt': 1, 'zh-cn': 1, 'id': 1}
# Number of deleted rows: 268

# %%
#test result and store the result in another dataframe 
df_result_before_trans = df.copy(deep=True)
df_result_before_trans
# Out:
#                    name  original_idx                 website_url  \
# 0               itravel             0     https://www.itravel.de/
# 1               kunveno             2          https://kunveno.de
# 3                Scopas             4      https://www.scopas.io/
# 4           studymaniac             5      https://studymaniac.de
# 6                Aicone             9         http://www.ai-c.one
# ...                 ...           ...                         ...
# 3284             Coleap          4994         https://coleap.com/
# 3285  Trade Machines FI          4995    http://trademachines.com
# 3286             Yasoon          4996          http://yasoon.com/
# 3287         Phoneboost          4997  https://www.phoneboost.de/
# 3288        Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text language
# 0     itravel Telefonische Beratung +49 221 8282 888...       de
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...       de
# 3     ScopasWe're working on something new.Check it ...       en
# 4     Studymaniac - erfolgreich Studieren Open main ...       de
# 6     Aicone - Artificial Intelligence Cloud One | A...       en
# ...                                                 ...      ...
# 3284  Coleap Transform your content into incomeTurn ...       en
# 3285  ▷ All used industrial equipment online on Trad...       en
# 3286  Home - yasoon Patrick Partner Manager Get in t...       en
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...       de
# 3288  Gaius - Dein Personal Legal Assistant Homepage...       de
#
# [3021 rows x 5 columns]

# %%
#load the result from steps before
df = df_result_before_trans.copy()
df
# Out:
#                    name  original_idx                 website_url  \
# 0               itravel             0     https://www.itravel.de/
# 1               kunveno             2          https://kunveno.de
# 3                Scopas             4      https://www.scopas.io/
# 4           studymaniac             5      https://studymaniac.de
# 6                Aicone             9         http://www.ai-c.one
# ...                 ...           ...                         ...
# 3284             Coleap          4994         https://coleap.com/
# 3285  Trade Machines FI          4995    http://trademachines.com
# 3286             Yasoon          4996          http://yasoon.com/
# 3287         Phoneboost          4997  https://www.phoneboost.de/
# 3288        Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text language
# 0     itravel Telefonische Beratung +49 221 8282 888...       de
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...       de
# 3     ScopasWe're working on something new.Check it ...       en
# 4     Studymaniac - erfolgreich Studieren Open main ...       de
# 6     Aicone - Artificial Intelligence Cloud One | A...       en
# ...                                                 ...      ...
# 3284  Coleap Transform your content into incomeTurn ...       en
# 3285  ▷ All used industrial equipment online on Trad...       en
# 3286  Home - yasoon Patrick Partner Manager Get in t...       en
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...       de
# 3288  Gaius - Dein Personal Legal Assistant Homepage...       de
#
# [3021 rows x 5 columns]

# %%
choosen_lang ='en'

df[f'website_text_in_{choosen_lang}'] = None
df
# Out:
#                    name  original_idx                 website_url  \
# 0               itravel             0     https://www.itravel.de/
# 1               kunveno             2          https://kunveno.de
# 3                Scopas             4      https://www.scopas.io/
# 4           studymaniac             5      https://studymaniac.de
# 6                Aicone             9         http://www.ai-c.one
# ...                 ...           ...                         ...
# 3284             Coleap          4994         https://coleap.com/
# 3285  Trade Machines FI          4995    http://trademachines.com
# 3286             Yasoon          4996          http://yasoon.com/
# 3287         Phoneboost          4997  https://www.phoneboost.de/
# 3288        Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text language  \
# 0     itravel Telefonische Beratung +49 221 8282 888...       de
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...       de
# 3     ScopasWe're working on something new.Check it ...       en
# 4     Studymaniac - erfolgreich Studieren Open main ...       de
# 6     Aicone - Artificial Intelligence Cloud One | A...       en
# ...                                                 ...      ...
# 3284  Coleap Transform your content into incomeTurn ...       en
# 3285  ▷ All used industrial equipment online on Trad...       en
# 3286  Home - yasoon Patrick Partner Manager Get in t...       en
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...       de
# 3288  Gaius - Dein Personal Legal Assistant Homepage...       de
#
#      website_text_in_en
# 0                  None
# 1                  None
# 3                  None
# 4                  None
# 6                  None
# ...                 ...
# 3284               None
# 3285               None
# 3286               None
# 3287               None
# 3288               None
#
# [3021 rows x 6 columns]

# %%
from deep_translator import GoogleTranslator

#translate all texts which are not written in the choosen language 
for index, row in df.iterrows():
    if row[f'website_text_in_{choosen_lang}'] == None:
        translated_chunks=[]
        if len(row['website_text']) > 4900:
            # Split the text into smaller chunks for translation
            chunk_size = 4900  # Choose chank size
            chunks = [row['website_text'][i:i+chunk_size] for i in range(0, len(row['website_text']), chunk_size)]

            # Translate each chunk and join them back
            translated_chunks = []
            for chunk in chunks:
                translation = GoogleTranslator(source='auto', target=choosen_lang).translate(chunk)
                translated_chunks.append(translation)
                translation = ' '.join(translated_chunks)
            print(f"Text at index {index} was translated.")   
        else:
            translation = GoogleTranslator(source='auto', target=choosen_lang).translate(row['website_text'])
            df.at[index, f'website_text_in_{choosen_lang}'] = translation
            print(f"Text at index {index} was translated.")
    if row[f'website_text_in_{choosen_lang}'] == None:
        df.at[index, f'website_text_in_{choosen_lang}'] = row[f'website_text']
df.rename(columns={'language': 'original_language'}, inplace=True)
# Out:
# Text at index 0 was translated.
# Text at index 1 was translated.
# Text at index 3 was translated.
# Text at index 4 was translated.
# Text at index 6 was translated.
# Text at index 7 was translated.
# Text at index 8 was translated.
# Text at index 9 was translated.
# Text at index 10 was translated.
# Text at index 11 was translated.
# Text at index 12 was translated.
# Text at index 13 was translated.
# Text at index 14 was translated.
# Text at index 15 was translated.
# Text at index 16 was translated.
# Text at index 17 was translated.
# Text at index 18 was translated.
# Text at index 19 was translated.
# Text at index 21 was translated.
# Text at index 23 was translated.
# Text at index 24 was translated.
# Text at index 25 was translated.
# Text at index 26 was translated.
# Text at index 27 was translated.
# Text at index 28 was translated.
# Text at index 29 was translated.
# Text at index 30 was translated.
# Text at index 31 was translated.
# Text at index 32 was translated.
# Text at index 33 was translated.
# Text at index 34 was translated.
# Text at index 35 was translated.
# Text at index 36 was translated.
# Text at index 37 was translated.
# Text at index 38 was translated.
# Text at index 39 was translated.
# Text at index 40 was translated.
# Text at index 41 was translated.
# Text at index 42 was translated.
# Text at index 43 was translated.
# Text at index 44 was translated.
# Text at index 45 was translated.
# Text at index 46 was translated.
# Text at index 47 was translated.
# Text at index 48 was translated.
# Text at index 49 was translated.
# Text at index 50 was translated.
# Text at index 51 was translated.
# Text at index 52 was translated.
# Text at index 53 was translated.
# Text at index 54 was translated.
# Text at index 55 was translated.
# Text at index 56 was translated.
# Text at index 57 was translated.
# Text at index 58 was translated.
# Text at index 59 was translated.
# Text at index 60 was translated.
# Text at index 61 was translated.
# Text at index 62 was translated.
# Text at index 63 was translated.
# Text at index 64 was translated.
# Text at index 65 was translated.
# Text at index 66 was translated.
# Text at index 68 was translated.
# Text at index 69 was translated.
# Text at index 70 was translated.
# Text at index 71 was translated.
# Text at index 72 was translated.
# Text at index 73 was translated.
# Text at index 74 was translated.
# Text at index 75 was translated.
# Text at index 76 was translated.
# Text at index 77 was translated.
# Text at index 78 was translated.
# Text at index 79 was translated.
# Text at index 80 was translated.
# Text at index 81 was translated.
# Text at index 82 was translated.
# Text at index 84 was translated.
# Text at index 85 was translated.
# Text at index 86 was translated.
# Text at index 87 was translated.
# Text at index 88 was translated.
# Text at index 89 was translated.
# Text at index 90 was translated.
# Text at index 91 was translated.
# Text at index 92 was translated.
# Text at index 93 was translated.
# Text at index 94 was translated.
# Text at index 95 was translated.
# Text at index 96 was translated.
# Text at index 98 was translated.
# Text at index 99 was translated.
# Text at index 100 was translated.
# Text at index 101 was translated.
# Text at index 102 was translated.
# Text at index 103 was translated.
# Text at index 104 was translated.
# Text at index 105 was translated.
# Text at index 106 was translated.
# Text at index 107 was translated.
# Text at index 109 was translated.
# Text at index 110 was translated.
# Text at index 111 was translated.
# Text at index 112 was translated.
# Text at index 113 was translated.
# Text at index 114 was translated.
# Text at index 115 was translated.
# Text at index 117 was translated.
# Text at index 118 was translated.
# Text at index 119 was translated.
# Text at index 122 was translated.
# Text at index 123 was translated.
# Text at index 124 was translated.
# Text at index 125 was translated.
# Text at index 126 was translated.
# Text at index 127 was translated.
# Text at index 128 was translated.
# Text at index 129 was translated.
# Text at index 130 was translated.
# Text at index 131 was translated.
# Text at index 132 was translated.
# Text at index 133 was translated.
# Text at index 134 was translated.
# Text at index 135 was translated.
# Text at index 136 was translated.
# Text at index 137 was translated.
# Text at index 138 was translated.
# Text at index 140 was translated.
# Text at index 141 was translated.
# Text at index 142 was translated.
# Text at index 143 was translated.
# Text at index 144 was translated.
# Text at index 145 was translated.
# Text at index 146 was translated.
# Text at index 147 was translated.
# Text at index 148 was translated.
# Text at index 149 was translated.
# Text at index 150 was translated.
# Text at index 151 was translated.
# Text at index 152 was translated.
# Text at index 153 was translated.
# Text at index 154 was translated.
# Text at index 155 was translated.
# Text at index 156 was translated.
# Text at index 157 was translated.
# Text at index 158 was translated.
# Text at index 159 was translated.
# Text at index 160 was translated.
# Text at index 162 was translated.
# Text at index 163 was translated.
# Text at index 164 was translated.
# Text at index 165 was translated.
# Text at index 166 was translated.
# Text at index 167 was translated.
# Text at index 168 was translated.
# Text at index 169 was translated.
# Text at index 170 was translated.
# Text at index 171 was translated.
# Text at index 172 was translated.
# Text at index 173 was translated.
# Text at index 174 was translated.
# Text at index 175 was translated.
# Text at index 176 was translated.
# Text at index 177 was translated.
# Text at index 178 was translated.
# Text at index 179 was translated.
# Text at index 181 was translated.
# Text at index 182 was translated.
# Text at index 183 was translated.
# Text at index 184 was translated.
# Text at index 185 was translated.
# Text at index 186 was translated.
# Text at index 187 was translated.
# Text at index 188 was translated.
# Text at index 189 was translated.
# Text at index 190 was translated.
# Text at index 191 was translated.
# Text at index 193 was translated.
# Text at index 194 was translated.
# Text at index 195 was translated.
# Text at index 196 was translated.
# Text at index 197 was translated.
# Text at index 198 was translated.
# Text at index 199 was translated.
# Text at index 200 was translated.
# Text at index 201 was translated.
# Text at index 202 was translated.
# Text at index 203 was translated.
# Text at index 204 was translated.
# Text at index 205 was translated.
# Text at index 206 was translated.
# Text at index 207 was translated.
# Text at index 208 was translated.
# Text at index 210 was translated.
# Text at index 211 was translated.
# Text at index 212 was translated.
# Text at index 213 was translated.
# Text at index 215 was translated.
# Text at index 216 was translated.
# Text at index 217 was translated.
# Text at index 219 was translated.
# Text at index 220 was translated.
# Text at index 221 was translated.
# Text at index 222 was translated.
# Text at index 223 was translated.
# Text at index 224 was translated.
# Text at index 225 was translated.
# Text at index 226 was translated.
# Text at index 227 was translated.
# Text at index 228 was translated.
# Text at index 229 was translated.
# Text at index 230 was translated.
# Text at index 231 was translated.
# Text at index 232 was translated.
# Text at index 233 was translated.
# Text at index 234 was translated.
# Text at index 235 was translated.
# Text at index 236 was translated.
# Text at index 237 was translated.
# Text at index 239 was translated.
# Text at index 240 was translated.
# Text at index 241 was translated.
# Text at index 242 was translated.
# Text at index 243 was translated.
# Text at index 244 was translated.
# Text at index 245 was translated.
# Text at index 246 was translated.
# Text at index 247 was translated.
# Text at index 248 was translated.
# Text at index 249 was translated.
# Text at index 250 was translated.
# Text at index 251 was translated.
# Text at index 252 was translated.
# Text at index 253 was translated.
# Text at index 254 was translated.
# Text at index 255 was translated.
# Text at index 256 was translated.
# Text at index 257 was translated.
# Text at index 258 was translated.
# Text at index 259 was translated.
# Text at index 260 was translated.
# Text at index 261 was translated.
# Text at index 262 was translated.
# Text at index 263 was translated.
# Text at index 264 was translated.
# Text at index 265 was translated.
# Text at index 266 was translated.
# Text at index 267 was translated.
# Text at index 268 was translated.
# Text at index 269 was translated.
# Text at index 270 was translated.
# Text at index 272 was translated.
# Text at index 273 was translated.
# Text at index 274 was translated.
# Text at index 275 was translated.
# Text at index 276 was translated.
# Text at index 277 was translated.
# Text at index 278 was translated.
# Text at index 279 was translated.
# Text at index 280 was translated.
# Text at index 281 was translated.
# Text at index 282 was translated.
# Text at index 283 was translated.
# Text at index 284 was translated.
# Text at index 285 was translated.
# Text at index 287 was translated.
# Text at index 288 was translated.
# Text at index 289 was translated.
# Text at index 290 was translated.
# Text at index 291 was translated.
# Text at index 292 was translated.
# Text at index 293 was translated.
# Text at index 294 was translated.
# Text at index 295 was translated.
# Text at index 296 was translated.
# Text at index 297 was translated.
# Text at index 298 was translated.
# Text at index 299 was translated.
# Text at index 300 was translated.
# Text at index 301 was translated.
# Text at index 302 was translated.
# Text at index 304 was translated.
# Text at index 305 was translated.
# Text at index 306 was translated.
# Text at index 307 was translated.
# Text at index 308 was translated.
# Text at index 309 was translated.
# Text at index 310 was translated.
# Text at index 311 was translated.
# Text at index 312 was translated.
# Text at index 313 was translated.
# Text at index 314 was translated.
# Text at index 315 was translated.
# Text at index 316 was translated.
# Text at index 317 was translated.
# Text at index 318 was translated.
# Text at index 319 was translated.
# Text at index 320 was translated.
# Text at index 322 was translated.
# Text at index 323 was translated.
# Text at index 324 was translated.
# Text at index 325 was translated.
# Text at index 326 was translated.
# Text at index 327 was translated.
# Text at index 328 was translated.
# Text at index 329 was translated.
# Text at index 330 was translated.
# Text at index 331 was translated.
# Text at index 332 was translated.
# Text at index 333 was translated.
# Text at index 334 was translated.
# Text at index 335 was translated.
# Text at index 336 was translated.
# Text at index 337 was translated.
# Text at index 338 was translated.
# Text at index 340 was translated.
# Text at index 341 was translated.
# Text at index 342 was translated.
# Text at index 343 was translated.
# Text at index 344 was translated.
# Text at index 345 was translated.
# Text at index 346 was translated.
# Text at index 347 was translated.
# Text at index 348 was translated.
# Text at index 349 was translated.
# Text at index 350 was translated.
# Text at index 351 was translated.
# Text at index 352 was translated.
# Text at index 353 was translated.
# Text at index 354 was translated.
# Text at index 355 was translated.
# Text at index 356 was translated.
# Text at index 358 was translated.
# Text at index 359 was translated.
# Text at index 360 was translated.
# Text at index 361 was translated.
# Text at index 363 was translated.
# Text at index 364 was translated.
# Text at index 365 was translated.
# Text at index 366 was translated.
# Text at index 367 was translated.
# Text at index 368 was translated.
# Text at index 369 was translated.
# Text at index 370 was translated.
# Text at index 371 was translated.
# Text at index 372 was translated.
# Text at index 373 was translated.
# Text at index 374 was translated.
# Text at index 375 was translated.
# Text at index 376 was translated.
# Text at index 377 was translated.
# Text at index 379 was translated.
# Text at index 380 was translated.
# Text at index 381 was translated.
# Text at index 384 was translated.
# Text at index 385 was translated.
# Text at index 386 was translated.
# Text at index 387 was translated.
# Text at index 388 was translated.
# Text at index 389 was translated.
# Text at index 390 was translated.
# Text at index 391 was translated.
# Text at index 392 was translated.
# Text at index 393 was translated.
# Text at index 394 was translated.
# Text at index 395 was translated.
# Text at index 396 was translated.
# Text at index 398 was translated.
# Text at index 399 was translated.
# Text at index 400 was translated.
# Text at index 401 was translated.
# Text at index 402 was translated.
# Text at index 403 was translated.
# Text at index 404 was translated.
# Text at index 405 was translated.
# Text at index 406 was translated.
# Text at index 407 was translated.
# Text at index 408 was translated.
# Text at index 409 was translated.
# Text at index 410 was translated.
# Text at index 411 was translated.
# Text at index 412 was translated.
# Text at index 413 was translated.
# Text at index 414 was translated.
# Text at index 415 was translated.
# Text at index 416 was translated.
# Text at index 417 was translated.
# Text at index 418 was translated.
# Text at index 419 was translated.
# Text at index 420 was translated.
# Text at index 421 was translated.
# Text at index 422 was translated.
# Text at index 423 was translated.
# Text at index 424 was translated.
# Text at index 425 was translated.
# Text at index 426 was translated.
# Text at index 427 was translated.
# Text at index 428 was translated.
# Text at index 429 was translated.
# Text at index 430 was translated.
# Text at index 431 was translated.
# Text at index 432 was translated.
# Text at index 433 was translated.
# Text at index 435 was translated.
# Text at index 436 was translated.
# Text at index 437 was translated.
# Text at index 438 was translated.
# Text at index 440 was translated.
# Text at index 441 was translated.
# Text at index 442 was translated.
# Text at index 443 was translated.
# Text at index 444 was translated.
# Text at index 445 was translated.
# Text at index 446 was translated.
# Text at index 447 was translated.
# Text at index 448 was translated.
# Text at index 449 was translated.
# Text at index 450 was translated.
# Text at index 451 was translated.
# Text at index 452 was translated.
# Text at index 453 was translated.
# Text at index 459 was translated.
# Text at index 460 was translated.
# Text at index 461 was translated.
# Text at index 462 was translated.
# Text at index 464 was translated.
# Text at index 465 was translated.
# Text at index 466 was translated.
# Text at index 467 was translated.
# Text at index 468 was translated.
# Text at index 469 was translated.
# Text at index 470 was translated.
# Text at index 471 was translated.
# Text at index 472 was translated.
# Text at index 473 was translated.
# Text at index 474 was translated.
# Text at index 475 was translated.
# Text at index 477 was translated.
# Text at index 478 was translated.
# Text at index 479 was translated.
# Text at index 480 was translated.
# Text at index 481 was translated.
# Text at index 482 was translated.
# Text at index 483 was translated.
# Text at index 484 was translated.
# Text at index 485 was translated.
# Text at index 486 was translated.
# Text at index 487 was translated.
# Text at index 488 was translated.
# Text at index 489 was translated.
# Text at index 491 was translated.
# Text at index 493 was translated.
# Text at index 494 was translated.
# Text at index 495 was translated.
# Text at index 496 was translated.
# Text at index 497 was translated.
# Text at index 498 was translated.
# Text at index 499 was translated.
# Text at index 500 was translated.
# Text at index 501 was translated.
# Text at index 502 was translated.
# Text at index 503 was translated.
# Text at index 504 was translated.
# Text at index 505 was translated.
# Text at index 506 was translated.
# Text at index 507 was translated.
# Text at index 508 was translated.
# Text at index 509 was translated.
# Text at index 510 was translated.
# Text at index 511 was translated.
# Text at index 512 was translated.
# Text at index 513 was translated.
# Text at index 515 was translated.
# Text at index 517 was translated.
# Text at index 518 was translated.
# Text at index 519 was translated.
# Text at index 521 was translated.
# Text at index 523 was translated.
# Text at index 524 was translated.
# Text at index 526 was translated.
# Text at index 527 was translated.
# Text at index 528 was translated.
# Text at index 529 was translated.
# Text at index 530 was translated.
# Text at index 531 was translated.
# Text at index 532 was translated.
# Text at index 533 was translated.
# Text at index 534 was translated.
# Text at index 535 was translated.
# Text at index 536 was translated.
# Text at index 537 was translated.
# Text at index 539 was translated.
# Text at index 540 was translated.
# Text at index 541 was translated.
# Text at index 542 was translated.
# Text at index 543 was translated.
# Text at index 544 was translated.
# Text at index 545 was translated.
# Text at index 546 was translated.
# Text at index 547 was translated.
# Text at index 548 was translated.
# Text at index 549 was translated.
# Text at index 550 was translated.
# Text at index 551 was translated.
# Text at index 552 was translated.
# Text at index 553 was translated.
# Text at index 554 was translated.
# Text at index 555 was translated.
# Text at index 557 was translated.
# Text at index 558 was translated.
# Text at index 559 was translated.
# Text at index 560 was translated.
# Text at index 562 was translated.
# Text at index 563 was translated.
# Text at index 565 was translated.
# Text at index 566 was translated.
# Text at index 567 was translated.
# Text at index 568 was translated.
# Text at index 570 was translated.
# Text at index 571 was translated.
# Text at index 572 was translated.
# Text at index 573 was translated.
# Text at index 574 was translated.
# Text at index 575 was translated.
# Text at index 576 was translated.
# Text at index 577 was translated.
# Text at index 578 was translated.
# Text at index 579 was translated.
# Text at index 580 was translated.
# Text at index 581 was translated.
# Text at index 582 was translated.
# Text at index 583 was translated.
# Text at index 584 was translated.
# Text at index 585 was translated.
# Text at index 586 was translated.
# Text at index 587 was translated.
# Text at index 588 was translated.
# Text at index 589 was translated.
# Text at index 590 was translated.
# Text at index 591 was translated.
# Text at index 592 was translated.
# Text at index 594 was translated.
# Text at index 595 was translated.
# Text at index 596 was translated.
# Text at index 598 was translated.
# Text at index 600 was translated.
# Text at index 602 was translated.
# Text at index 603 was translated.
# Text at index 604 was translated.
# Text at index 605 was translated.
# Text at index 606 was translated.
# Text at index 607 was translated.
# Text at index 608 was translated.
# Text at index 609 was translated.
# Text at index 610 was translated.
# Text at index 611 was translated.
# Text at index 612 was translated.
# Text at index 615 was translated.
# Text at index 616 was translated.
# Text at index 617 was translated.
# Text at index 618 was translated.
# Text at index 619 was translated.
# Text at index 620 was translated.
# Text at index 621 was translated.
# Text at index 622 was translated.
# Text at index 623 was translated.
# Text at index 624 was translated.
# Text at index 626 was translated.
# Text at index 627 was translated.
# Text at index 628 was translated.
# Text at index 629 was translated.
# Text at index 630 was translated.
# Text at index 631 was translated.
# Text at index 633 was translated.
# Text at index 634 was translated.
# Text at index 635 was translated.
# Text at index 636 was translated.
# Text at index 637 was translated.
# Text at index 638 was translated.
# Text at index 639 was translated.
# Text at index 641 was translated.
# Text at index 642 was translated.
# Text at index 643 was translated.
# Text at index 644 was translated.
# Text at index 645 was translated.
# Text at index 646 was translated.
# Text at index 647 was translated.
# Text at index 648 was translated.
# Text at index 650 was translated.
# Text at index 651 was translated.
# Text at index 652 was translated.
# Text at index 653 was translated.
# Text at index 654 was translated.
# Text at index 655 was translated.
# Text at index 657 was translated.
# Text at index 658 was translated.
# Text at index 659 was translated.
# Text at index 660 was translated.
# Text at index 661 was translated.
# Text at index 662 was translated.
# Text at index 663 was translated.
# Text at index 665 was translated.
# Text at index 666 was translated.
# Text at index 667 was translated.
# Text at index 668 was translated.
# Text at index 669 was translated.
# Text at index 670 was translated.
# Text at index 671 was translated.
# Text at index 672 was translated.
# Text at index 673 was translated.
# Text at index 674 was translated.
# Text at index 675 was translated.
# Text at index 676 was translated.
# Text at index 678 was translated.
# Text at index 679 was translated.
# Text at index 680 was translated.
# Text at index 681 was translated.
# Text at index 682 was translated.
# Text at index 683 was translated.
# Text at index 684 was translated.
# Text at index 685 was translated.
# Text at index 686 was translated.
# Text at index 689 was translated.
# Text at index 690 was translated.
# Text at index 691 was translated.
# Text at index 692 was translated.
# Text at index 693 was translated.
# Text at index 694 was translated.
# Text at index 695 was translated.
# Text at index 696 was translated.
# Text at index 697 was translated.
# Text at index 698 was translated.
# Text at index 699 was translated.
# Text at index 700 was translated.
# Text at index 701 was translated.
# Text at index 702 was translated.
# Text at index 703 was translated.
# Text at index 704 was translated.
# Text at index 705 was translated.
# Text at index 706 was translated.
# Text at index 707 was translated.
# Text at index 708 was translated.
# Text at index 709 was translated.
# Text at index 710 was translated.
# Text at index 712 was translated.
# Text at index 713 was translated.
# Text at index 714 was translated.
# Text at index 715 was translated.
# Text at index 716 was translated.
# Text at index 717 was translated.
# Text at index 718 was translated.
# Text at index 720 was translated.
# Text at index 721 was translated.
# Text at index 722 was translated.
# Text at index 723 was translated.
# Text at index 724 was translated.
# Text at index 725 was translated.
# Text at index 726 was translated.
# Text at index 727 was translated.
# Text at index 728 was translated.
# Text at index 729 was translated.
# Text at index 730 was translated.
# Text at index 731 was translated.
# Text at index 732 was translated.
# Text at index 733 was translated.
# Text at index 735 was translated.
# Text at index 736 was translated.
# Text at index 737 was translated.
# Text at index 738 was translated.
# Text at index 739 was translated.
# Text at index 740 was translated.
# Text at index 741 was translated.
# Text at index 742 was translated.
# Text at index 743 was translated.
# Text at index 744 was translated.
# Text at index 745 was translated.
# Text at index 746 was translated.
# Text at index 747 was translated.
# Text at index 748 was translated.
# Text at index 749 was translated.
# Text at index 750 was translated.
# Text at index 752 was translated.
# Text at index 753 was translated.
# Text at index 754 was translated.
# Text at index 755 was translated.
# Text at index 756 was translated.
# Text at index 757 was translated.
# Text at index 758 was translated.
# Text at index 759 was translated.
# Text at index 760 was translated.
# Text at index 761 was translated.
# Text at index 762 was translated.
# Text at index 763 was translated.
# Text at index 764 was translated.
# Text at index 765 was translated.
# Text at index 766 was translated.
# Text at index 767 was translated.
# Text at index 768 was translated.
# Text at index 769 was translated.
# Text at index 770 was translated.
# Text at index 771 was translated.
# Text at index 772 was translated.
# Text at index 773 was translated.
# Text at index 774 was translated.
# Text at index 775 was translated.
# Text at index 776 was translated.
# Text at index 777 was translated.
# Text at index 778 was translated.
# Text at index 779 was translated.
# Text at index 780 was translated.
# Text at index 781 was translated.
# Text at index 782 was translated.
# Text at index 783 was translated.
# Text at index 784 was translated.
# Text at index 785 was translated.
# Text at index 786 was translated.
# Text at index 787 was translated.
# Text at index 788 was translated.
# Text at index 789 was translated.
# Text at index 790 was translated.
# Text at index 791 was translated.
# Text at index 792 was translated.
# Text at index 793 was translated.
# Text at index 794 was translated.
# Text at index 795 was translated.
# Text at index 796 was translated.
# Text at index 797 was translated.
# Text at index 798 was translated.
# Text at index 799 was translated.
# Text at index 800 was translated.
# Text at index 801 was translated.
# Text at index 802 was translated.
# Text at index 803 was translated.
# Text at index 804 was translated.
# Text at index 805 was translated.
# Text at index 807 was translated.
# Text at index 808 was translated.
# Text at index 809 was translated.
# Text at index 810 was translated.
# Text at index 811 was translated.
# Text at index 812 was translated.
# Text at index 814 was translated.
# Text at index 815 was translated.
# Text at index 816 was translated.
# Text at index 817 was translated.
# Text at index 819 was translated.
# Text at index 820 was translated.
# Text at index 821 was translated.
# Text at index 822 was translated.
# Text at index 823 was translated.
# Text at index 824 was translated.
# Text at index 825 was translated.
# Text at index 826 was translated.
# Text at index 827 was translated.
# Text at index 828 was translated.
# Text at index 829 was translated.
# Text at index 831 was translated.
# Text at index 833 was translated.
# Text at index 834 was translated.
# Text at index 835 was translated.
# Text at index 836 was translated.
# Text at index 837 was translated.
# Text at index 838 was translated.
# Text at index 839 was translated.
# Text at index 840 was translated.
# Text at index 841 was translated.
# Text at index 842 was translated.
# Text at index 843 was translated.
# Text at index 844 was translated.
# Text at index 845 was translated.
# Text at index 846 was translated.
# Text at index 847 was translated.
# Text at index 848 was translated.
# Text at index 849 was translated.
# Text at index 850 was translated.
# Text at index 851 was translated.
# Text at index 852 was translated.
# Text at index 853 was translated.
# Text at index 855 was translated.
# Text at index 856 was translated.
# Text at index 857 was translated.
# Text at index 858 was translated.
# Text at index 859 was translated.
# Text at index 860 was translated.
# Text at index 861 was translated.
# Text at index 862 was translated.
# Text at index 863 was translated.
# Text at index 864 was translated.
# Text at index 865 was translated.
# Text at index 866 was translated.
# Text at index 867 was translated.
# Text at index 868 was translated.
# Text at index 869 was translated.
# Text at index 870 was translated.
# Text at index 871 was translated.
# Text at index 872 was translated.
# Text at index 873 was translated.
# Text at index 874 was translated.
# Text at index 875 was translated.
# Text at index 876 was translated.
# Text at index 879 was translated.
# Text at index 880 was translated.
# Text at index 881 was translated.
# Text at index 882 was translated.
# Text at index 883 was translated.
# Text at index 884 was translated.
# Text at index 886 was translated.
# Text at index 887 was translated.
# Text at index 888 was translated.
# Text at index 889 was translated.
# Text at index 890 was translated.
# Text at index 891 was translated.
# Text at index 893 was translated.
# Text at index 894 was translated.
# Text at index 895 was translated.
# Text at index 896 was translated.
# Text at index 897 was translated.
# Text at index 898 was translated.
# Text at index 899 was translated.
# Text at index 900 was translated.
# Text at index 901 was translated.
# Text at index 902 was translated.
# Text at index 903 was translated.
# Text at index 904 was translated.
# Text at index 906 was translated.
# Text at index 907 was translated.
# Text at index 909 was translated.
# Text at index 910 was translated.
# Text at index 911 was translated.
# Text at index 912 was translated.
# Text at index 913 was translated.
# Text at index 915 was translated.
# Text at index 916 was translated.
# Text at index 917 was translated.
# Text at index 918 was translated.
# Text at index 919 was translated.
# Text at index 920 was translated.
# Text at index 921 was translated.
# Text at index 922 was translated.
# Text at index 923 was translated.
# Text at index 925 was translated.
# Text at index 926 was translated.
# Text at index 927 was translated.
# Text at index 928 was translated.
# Text at index 929 was translated.
# Text at index 930 was translated.
# Text at index 931 was translated.
# Text at index 933 was translated.
# Text at index 934 was translated.
# Text at index 935 was translated.
# Text at index 936 was translated.
# Text at index 938 was translated.
# Text at index 939 was translated.
# Text at index 940 was translated.
# Text at index 941 was translated.
# Text at index 942 was translated.
# Text at index 943 was translated.
# Text at index 944 was translated.
# Text at index 945 was translated.
# Text at index 946 was translated.
# Text at index 947 was translated.
# Text at index 948 was translated.
# Text at index 949 was translated.
# Text at index 950 was translated.
# Text at index 951 was translated.
# Text at index 952 was translated.
# Text at index 954 was translated.
# Text at index 955 was translated.
# Text at index 958 was translated.
# Text at index 959 was translated.
# Text at index 960 was translated.
# Text at index 961 was translated.
# Text at index 962 was translated.
# Text at index 963 was translated.
# Text at index 964 was translated.
# Text at index 965 was translated.
# Text at index 966 was translated.
# Text at index 967 was translated.
# Text at index 969 was translated.
# Text at index 970 was translated.
# Text at index 971 was translated.
# Text at index 972 was translated.
# Text at index 974 was translated.
# Text at index 975 was translated.
# Text at index 977 was translated.
# Text at index 978 was translated.
# Text at index 980 was translated.
# Text at index 981 was translated.
# Text at index 983 was translated.
# Text at index 985 was translated.
# Text at index 986 was translated.
# Text at index 987 was translated.
# Text at index 988 was translated.
# Text at index 989 was translated.
# Text at index 990 was translated.
# Text at index 991 was translated.
# Text at index 992 was translated.
# Text at index 993 was translated.
# Text at index 994 was translated.
# Text at index 996 was translated.
# Text at index 997 was translated.
# Text at index 998 was translated.
# Text at index 999 was translated.
# Text at index 1000 was translated.
# Text at index 1001 was translated.
# Text at index 1002 was translated.
# Text at index 1004 was translated.
# Text at index 1005 was translated.
# Text at index 1006 was translated.
# Text at index 1007 was translated.
# Text at index 1008 was translated.
# Text at index 1009 was translated.
# Text at index 1010 was translated.
# Text at index 1011 was translated.
# Text at index 1012 was translated.
# Text at index 1013 was translated.
# Text at index 1014 was translated.
# Text at index 1015 was translated.
# Text at index 1016 was translated.
# Text at index 1017 was translated.
# Text at index 1018 was translated.
# Text at index 1019 was translated.
# Text at index 1022 was translated.
# Text at index 1023 was translated.
# Text at index 1024 was translated.
# Text at index 1025 was translated.
# Text at index 1027 was translated.
# Text at index 1028 was translated.
# Text at index 1029 was translated.
# Text at index 1030 was translated.
# Text at index 1031 was translated.
# Text at index 1032 was translated.
# Text at index 1033 was translated.
# Text at index 1034 was translated.
# Text at index 1035 was translated.
# Text at index 1036 was translated.
# Text at index 1037 was translated.
# Text at index 1039 was translated.
# Text at index 1040 was translated.
# Text at index 1041 was translated.
# Text at index 1042 was translated.
# Text at index 1043 was translated.
# Text at index 1044 was translated.
# Text at index 1045 was translated.
# Text at index 1046 was translated.
# Text at index 1047 was translated.
# Text at index 1048 was translated.
# Text at index 1049 was translated.
# Text at index 1050 was translated.
# Text at index 1051 was translated.
# Text at index 1052 was translated.
# Text at index 1053 was translated.
# Text at index 1054 was translated.
# Text at index 1055 was translated.
# Text at index 1056 was translated.
# Text at index 1057 was translated.
# Text at index 1058 was translated.
# Text at index 1059 was translated.
# Text at index 1060 was translated.
# Text at index 1061 was translated.
# Text at index 1063 was translated.
# Text at index 1064 was translated.
# Text at index 1065 was translated.
# Text at index 1066 was translated.
# Text at index 1067 was translated.
# Text at index 1068 was translated.
# Text at index 1070 was translated.
# Text at index 1071 was translated.
# Text at index 1072 was translated.
# Text at index 1073 was translated.
# Text at index 1074 was translated.
# Text at index 1075 was translated.
# Text at index 1076 was translated.
# Text at index 1077 was translated.
# Text at index 1078 was translated.
# Text at index 1079 was translated.
# Text at index 1080 was translated.
# Text at index 1081 was translated.
# Text at index 1082 was translated.
# Text at index 1083 was translated.
# Text at index 1084 was translated.
# Text at index 1085 was translated.
# Text at index 1086 was translated.
# Text at index 1087 was translated.
# Text at index 1088 was translated.
# Text at index 1089 was translated.
# Text at index 1090 was translated.
# Text at index 1091 was translated.
# Text at index 1092 was translated.
# Text at index 1094 was translated.
# Text at index 1095 was translated.
# Text at index 1096 was translated.
# Text at index 1097 was translated.
# Text at index 1098 was translated.
# Text at index 1099 was translated.
# Text at index 1100 was translated.
# Text at index 1101 was translated.
# Text at index 1102 was translated.
# Text at index 1104 was translated.
# Text at index 1105 was translated.
# Text at index 1106 was translated.
# Text at index 1107 was translated.
# Text at index 1108 was translated.
# Text at index 1109 was translated.
# Text at index 1110 was translated.
# Text at index 1112 was translated.
# Text at index 1113 was translated.
# Text at index 1114 was translated.
# Text at index 1116 was translated.
# Text at index 1117 was translated.
# Text at index 1118 was translated.
# Text at index 1119 was translated.
# Text at index 1120 was translated.
# Text at index 1121 was translated.
# Text at index 1122 was translated.
# Text at index 1123 was translated.
# Text at index 1125 was translated.
# Text at index 1126 was translated.
# Text at index 1127 was translated.
# Text at index 1128 was translated.
# Text at index 1129 was translated.
# Text at index 1130 was translated.
# Text at index 1131 was translated.
# Text at index 1133 was translated.
# Text at index 1134 was translated.
# Text at index 1135 was translated.
# Text at index 1136 was translated.
# Text at index 1137 was translated.
# Text at index 1138 was translated.
# Text at index 1139 was translated.
# Text at index 1140 was translated.
# Text at index 1141 was translated.
# Text at index 1143 was translated.
# Text at index 1144 was translated.
# Text at index 1145 was translated.
# Text at index 1146 was translated.
# Text at index 1147 was translated.
# Text at index 1148 was translated.
# Text at index 1149 was translated.
# Text at index 1150 was translated.
# Text at index 1151 was translated.
# Text at index 1152 was translated.
# Text at index 1153 was translated.
# Text at index 1154 was translated.
# Text at index 1155 was translated.
# Text at index 1156 was translated.
# Text at index 1158 was translated.
# Text at index 1159 was translated.
# Text at index 1160 was translated.
# Text at index 1161 was translated.
# Text at index 1162 was translated.
# Text at index 1163 was translated.
# Text at index 1164 was translated.
# Text at index 1165 was translated.
# Text at index 1166 was translated.
# Text at index 1167 was translated.
# Text at index 1168 was translated.
# Text at index 1169 was translated.
# Text at index 1170 was translated.
# Text at index 1171 was translated.
# Text at index 1173 was translated.
# Text at index 1174 was translated.
# Text at index 1175 was translated.
# Text at index 1176 was translated.
# Text at index 1177 was translated.
# Text at index 1178 was translated.
# Text at index 1179 was translated.
# Text at index 1180 was translated.
# Text at index 1181 was translated.
# Text at index 1182 was translated.
# Text at index 1183 was translated.
# Text at index 1184 was translated.
# Text at index 1185 was translated.
# Text at index 1186 was translated.
# Text at index 1187 was translated.
# Text at index 1188 was translated.
# Text at index 1189 was translated.
# Text at index 1190 was translated.
# Text at index 1191 was translated.
# Text at index 1192 was translated.
# Text at index 1193 was translated.
# Text at index 1194 was translated.
# Text at index 1195 was translated.
# Text at index 1196 was translated.
# Text at index 1197 was translated.
# Text at index 1199 was translated.
# Text at index 1201 was translated.
# Text at index 1202 was translated.
# Text at index 1203 was translated.
# Text at index 1204 was translated.
# Text at index 1205 was translated.
# Text at index 1206 was translated.
# Text at index 1207 was translated.
# Text at index 1208 was translated.
# Text at index 1209 was translated.
# Text at index 1210 was translated.
# Text at index 1211 was translated.
# Text at index 1212 was translated.
# Text at index 1213 was translated.
# Text at index 1214 was translated.
# Text at index 1215 was translated.
# Text at index 1216 was translated.
# Text at index 1217 was translated.
# Text at index 1218 was translated.
# Text at index 1219 was translated.
# Text at index 1220 was translated.
# Text at index 1221 was translated.
# Text at index 1222 was translated.
# Text at index 1223 was translated.
# Text at index 1224 was translated.
# Text at index 1225 was translated.
# Text at index 1226 was translated.
# Text at index 1227 was translated.
# Text at index 1228 was translated.
# Text at index 1229 was translated.
# Text at index 1230 was translated.
# Text at index 1232 was translated.
# Text at index 1233 was translated.
# Text at index 1234 was translated.
# Text at index 1236 was translated.
# Text at index 1237 was translated.
# Text at index 1238 was translated.
# Text at index 1239 was translated.
# Text at index 1240 was translated.
# Text at index 1241 was translated.
# Text at index 1242 was translated.
# Text at index 1243 was translated.
# Text at index 1244 was translated.
# Text at index 1245 was translated.
# Text at index 1246 was translated.
# Text at index 1247 was translated.
# Text at index 1248 was translated.
# Text at index 1249 was translated.
# Text at index 1250 was translated.
# Text at index 1251 was translated.
# Text at index 1252 was translated.
# Text at index 1253 was translated.
# Text at index 1254 was translated.
# Text at index 1255 was translated.
# Text at index 1256 was translated.
# Text at index 1258 was translated.
# Text at index 1259 was translated.
# Text at index 1260 was translated.
# Text at index 1261 was translated.
# Text at index 1262 was translated.
# Text at index 1263 was translated.
# Text at index 1264 was translated.
# Text at index 1265 was translated.
# Text at index 1266 was translated.
# Text at index 1268 was translated.
# Text at index 1269 was translated.
# Text at index 1270 was translated.
# Text at index 1271 was translated.
# Text at index 1273 was translated.
# Text at index 1274 was translated.
# Text at index 1275 was translated.
# Text at index 1276 was translated.
# Text at index 1277 was translated.
# Text at index 1279 was translated.
# Text at index 1280 was translated.
# Text at index 1281 was translated.
# Text at index 1282 was translated.
# Text at index 1283 was translated.
# Text at index 1284 was translated.
# Text at index 1285 was translated.
# Text at index 1286 was translated.
# Text at index 1287 was translated.
# Text at index 1288 was translated.
# Text at index 1289 was translated.
# Text at index 1290 was translated.
# Text at index 1291 was translated.
# Text at index 1292 was translated.
# Text at index 1293 was translated.
# Text at index 1294 was translated.
# Text at index 1295 was translated.
# Text at index 1296 was translated.
# Text at index 1297 was translated.
# Text at index 1298 was translated.
# Text at index 1299 was translated.
# Text at index 1300 was translated.
# Text at index 1301 was translated.
# Text at index 1302 was translated.
# Text at index 1304 was translated.
# Text at index 1305 was translated.
# Text at index 1306 was translated.
# Text at index 1307 was translated.
# Text at index 1308 was translated.
# Text at index 1309 was translated.
# Text at index 1310 was translated.
# Text at index 1311 was translated.
# Text at index 1312 was translated.
# Text at index 1313 was translated.
# Text at index 1314 was translated.
# Text at index 1315 was translated.
# Text at index 1316 was translated.
# Text at index 1318 was translated.
# Text at index 1319 was translated.
# Text at index 1320 was translated.
# Text at index 1321 was translated.
# Text at index 1322 was translated.
# Text at index 1323 was translated.
# Text at index 1324 was translated.
# Text at index 1325 was translated.
# Text at index 1326 was translated.
# Text at index 1327 was translated.
# Text at index 1328 was translated.
# Text at index 1329 was translated.
# Text at index 1330 was translated.
# Text at index 1331 was translated.
# Text at index 1332 was translated.
# Text at index 1333 was translated.
# Text at index 1334 was translated.
# Text at index 1335 was translated.
# Text at index 1336 was translated.
# Text at index 1337 was translated.
# Text at index 1338 was translated.
# Text at index 1339 was translated.
# Text at index 1340 was translated.
# Text at index 1341 was translated.
# Text at index 1342 was translated.
# Text at index 1343 was translated.
# Text at index 1344 was translated.
# Text at index 1345 was translated.
# Text at index 1346 was translated.
# Text at index 1347 was translated.
# Text at index 1348 was translated.
# Text at index 1349 was translated.
# Text at index 1350 was translated.
# Text at index 1351 was translated.
# Text at index 1352 was translated.
# Text at index 1353 was translated.
# Text at index 1354 was translated.
# Text at index 1355 was translated.
# Text at index 1356 was translated.
# Text at index 1359 was translated.
# Text at index 1360 was translated.
# Text at index 1361 was translated.
# Text at index 1362 was translated.
# Text at index 1363 was translated.
# Text at index 1364 was translated.
# Text at index 1365 was translated.
# Text at index 1366 was translated.
# Text at index 1367 was translated.
# Text at index 1368 was translated.
# Text at index 1369 was translated.
# Text at index 1370 was translated.
# Text at index 1371 was translated.
# Text at index 1372 was translated.
# Text at index 1373 was translated.
# Text at index 1374 was translated.
# Text at index 1375 was translated.
# Text at index 1377 was translated.
# Text at index 1378 was translated.
# Text at index 1379 was translated.
# Text at index 1380 was translated.
# Text at index 1381 was translated.
# Text at index 1382 was translated.
# Text at index 1383 was translated.
# Text at index 1384 was translated.
# Text at index 1385 was translated.
# Text at index 1386 was translated.
# Text at index 1387 was translated.
# Text at index 1388 was translated.
# Text at index 1389 was translated.
# Text at index 1391 was translated.
# Text at index 1393 was translated.
# Text at index 1394 was translated.
# Text at index 1395 was translated.
# Text at index 1396 was translated.
# Text at index 1397 was translated.
# Text at index 1398 was translated.
# Text at index 1400 was translated.
# Text at index 1401 was translated.
# Text at index 1402 was translated.
# Text at index 1403 was translated.
# Text at index 1404 was translated.
# Text at index 1405 was translated.
# Text at index 1406 was translated.
# Text at index 1407 was translated.
# Text at index 1408 was translated.
# Text at index 1409 was translated.
# Text at index 1410 was translated.
# Text at index 1412 was translated.
# Text at index 1413 was translated.
# Text at index 1415 was translated.
# Text at index 1416 was translated.
# Text at index 1417 was translated.
# Text at index 1418 was translated.
# Text at index 1419 was translated.
# Text at index 1420 was translated.
# Text at index 1421 was translated.
# Text at index 1423 was translated.
# Text at index 1424 was translated.
# Text at index 1425 was translated.
# Text at index 1426 was translated.
# Text at index 1427 was translated.
# Text at index 1428 was translated.
# Text at index 1430 was translated.
# Text at index 1431 was translated.
# Text at index 1432 was translated.
# Text at index 1433 was translated.
# Text at index 1434 was translated.
# Text at index 1436 was translated.
# Text at index 1437 was translated.
# Text at index 1438 was translated.
# Text at index 1439 was translated.
# Text at index 1440 was translated.
# Text at index 1441 was translated.
# Text at index 1442 was translated.
# Text at index 1443 was translated.
# Text at index 1444 was translated.
# Text at index 1445 was translated.
# Text at index 1447 was translated.
# Text at index 1448 was translated.
# Text at index 1449 was translated.
# Text at index 1450 was translated.
# Text at index 1451 was translated.
# Text at index 1453 was translated.
# Text at index 1454 was translated.
# Text at index 1455 was translated.
# Text at index 1456 was translated.
# Text at index 1457 was translated.
# Text at index 1458 was translated.
# Text at index 1459 was translated.
# Text at index 1460 was translated.
# Text at index 1461 was translated.
# Text at index 1462 was translated.
# Text at index 1463 was translated.
# Text at index 1464 was translated.
# Text at index 1466 was translated.
# Text at index 1467 was translated.
# Text at index 1468 was translated.
# Text at index 1469 was translated.
# Text at index 1470 was translated.
# Text at index 1472 was translated.
# Text at index 1473 was translated.
# Text at index 1474 was translated.
# Text at index 1475 was translated.
# Text at index 1476 was translated.
# Text at index 1478 was translated.
# Text at index 1479 was translated.
# Text at index 1480 was translated.
# Text at index 1481 was translated.
# Text at index 1482 was translated.
# Text at index 1483 was translated.
# Text at index 1484 was translated.
# Text at index 1485 was translated.
# Text at index 1486 was translated.
# Text at index 1487 was translated.
# Text at index 1488 was translated.
# Text at index 1489 was translated.
# Text at index 1490 was translated.
# Text at index 1491 was translated.
# Text at index 1492 was translated.
# Text at index 1493 was translated.
# Text at index 1494 was translated.
# Text at index 1495 was translated.
# Text at index 1496 was translated.
# Text at index 1497 was translated.
# Text at index 1498 was translated.
# Text at index 1499 was translated.
# Text at index 1500 was translated.
# Text at index 1501 was translated.
# Text at index 1503 was translated.
# Text at index 1504 was translated.
# Text at index 1505 was translated.
# Text at index 1506 was translated.
# Text at index 1507 was translated.
# Text at index 1509 was translated.
# Text at index 1510 was translated.
# Text at index 1511 was translated.
# Text at index 1512 was translated.
# Text at index 1513 was translated.
# Text at index 1514 was translated.
# Text at index 1515 was translated.
# Text at index 1516 was translated.
# Text at index 1517 was translated.
# Text at index 1518 was translated.
# Text at index 1519 was translated.
# Text at index 1520 was translated.
# Text at index 1521 was translated.
# Text at index 1522 was translated.
# Text at index 1523 was translated.
# Text at index 1524 was translated.
# Text at index 1525 was translated.
# Text at index 1527 was translated.
# Text at index 1528 was translated.
# Text at index 1529 was translated.
# Text at index 1530 was translated.
# Text at index 1531 was translated.
# Text at index 1532 was translated.
# Text at index 1533 was translated.
# Text at index 1534 was translated.
# Text at index 1535 was translated.
# Text at index 1536 was translated.
# Text at index 1537 was translated.
# Text at index 1538 was translated.
# Text at index 1539 was translated.
# Text at index 1540 was translated.
# ...
# Text at index 2791 was translated.
# Text at index 2792 was translated.
# Text at index 2793 was translated.
# Text at index 2794 was translated.
# Text at index 2795 was translated.
# Text at index 2796 was translated.
# Text at index 2797 was translated.
# Text at index 2798 was translated.
# Text at index 2799 was translated.
# Text at index 2800 was translated.
# Text at index 2801 was translated.
# Text at index 2802 was translated.
# Text at index 2803 was translated.
# Text at index 2804 was translated.
# Text at index 2805 was translated.
# Text at index 2806 was translated.
# Text at index 2807 was translated.
# Text at index 2808 was translated.
# Text at index 2809 was translated.
# Text at index 2810 was translated.
# Text at index 2811 was translated.
# Text at index 2812 was translated.
# Text at index 2813 was translated.
# Text at index 2814 was translated.
# Text at index 2816 was translated.
# Text at index 2818 was translated.
# Text at index 2819 was translated.
# Text at index 2820 was translated.
# Text at index 2821 was translated.
# Text at index 2822 was translated.
# Text at index 2823 was translated.
# Text at index 2824 was translated.
# Text at index 2825 was translated.
# Text at index 2826 was translated.
# Text at index 2828 was translated.
# Text at index 2829 was translated.
# Text at index 2830 was translated.
# Text at index 2831 was translated.
# Text at index 2832 was translated.
# Text at index 2833 was translated.
# Text at index 2834 was translated.
# Text at index 2835 was translated.
# Text at index 2837 was translated.
# Text at index 2838 was translated.
# Text at index 2839 was translated.
# Text at index 2840 was translated.
# Text at index 2841 was translated.
# Text at index 2842 was translated.
# Text at index 2843 was translated.
# Text at index 2844 was translated.
# Text at index 2845 was translated.
# Text at index 2846 was translated.
# Text at index 2847 was translated.
# Text at index 2848 was translated.
# Text at index 2849 was translated.
# Text at index 2850 was translated.
# Text at index 2851 was translated.
# Text at index 2852 was translated.
# Text at index 2853 was translated.
# Text at index 2854 was translated.
# Text at index 2855 was translated.
# Text at index 2856 was translated.
# Text at index 2857 was translated.
# Text at index 2858 was translated.
# Text at index 2859 was translated.
# Text at index 2860 was translated.
# Text at index 2861 was translated.
# Text at index 2862 was translated.
# Text at index 2863 was translated.
# Text at index 2864 was translated.
# Text at index 2865 was translated.
# Text at index 2866 was translated.
# Text at index 2867 was translated.
# Text at index 2868 was translated.
# Text at index 2869 was translated.
# Text at index 2870 was translated.
# Text at index 2871 was translated.
# Text at index 2872 was translated.
# Text at index 2873 was translated.
# Text at index 2874 was translated.
# Text at index 2875 was translated.
# Text at index 2877 was translated.
# Text at index 2878 was translated.
# Text at index 2879 was translated.
# Text at index 2880 was translated.
# Text at index 2881 was translated.
# Text at index 2882 was translated.
# Text at index 2883 was translated.
# Text at index 2884 was translated.
# Text at index 2885 was translated.
# Text at index 2886 was translated.
# Text at index 2888 was translated.
# Text at index 2889 was translated.
# Text at index 2892 was translated.
# Text at index 2893 was translated.
# Text at index 2894 was translated.
# Text at index 2895 was translated.
# Text at index 2896 was translated.
# Text at index 2897 was translated.
# Text at index 2898 was translated.
# Text at index 2899 was translated.
# Text at index 2900 was translated.
# Text at index 2901 was translated.
# Text at index 2902 was translated.
# Text at index 2903 was translated.
# Text at index 2904 was translated.
# Text at index 2905 was translated.
# Text at index 2906 was translated.
# Text at index 2908 was translated.
# Text at index 2910 was translated.
# Text at index 2911 was translated.
# Text at index 2912 was translated.
# Text at index 2913 was translated.
# Text at index 2914 was translated.
# Text at index 2915 was translated.
# Text at index 2916 was translated.
# Text at index 2917 was translated.
# Text at index 2918 was translated.
# Text at index 2919 was translated.
# Text at index 2920 was translated.
# Text at index 2921 was translated.
# Text at index 2922 was translated.
# Text at index 2923 was translated.
# Text at index 2924 was translated.
# Text at index 2925 was translated.
# Text at index 2926 was translated.
# Text at index 2927 was translated.
# Text at index 2928 was translated.
# Text at index 2929 was translated.
# Text at index 2930 was translated.
# Text at index 2931 was translated.
# Text at index 2932 was translated.
# Text at index 2933 was translated.
# Text at index 2934 was translated.
# Text at index 2936 was translated.
# Text at index 2937 was translated.
# Text at index 2938 was translated.
# Text at index 2939 was translated.
# Text at index 2940 was translated.
# Text at index 2941 was translated.
# Text at index 2943 was translated.
# Text at index 2944 was translated.
# Text at index 2945 was translated.
# Text at index 2946 was translated.
# Text at index 2947 was translated.
# Text at index 2948 was translated.
# Text at index 2950 was translated.
# Text at index 2951 was translated.
# Text at index 2952 was translated.
# Text at index 2953 was translated.
# Text at index 2954 was translated.
# Text at index 2955 was translated.
# Text at index 2957 was translated.
# Text at index 2958 was translated.
# Text at index 2959 was translated.
# Text at index 2960 was translated.
# Text at index 2961 was translated.
# Text at index 2962 was translated.
# Text at index 2963 was translated.
# Text at index 2964 was translated.
# Text at index 2965 was translated.
# Text at index 2966 was translated.
# Text at index 2967 was translated.
# Text at index 2968 was translated.
# Text at index 2969 was translated.
# Text at index 2970 was translated.
# Text at index 2971 was translated.
# Text at index 2972 was translated.
# Text at index 2973 was translated.
# Text at index 2974 was translated.
# Text at index 2975 was translated.
# Text at index 2976 was translated.
# Text at index 2977 was translated.
# Text at index 2978 was translated.
# Text at index 2979 was translated.
# Text at index 2980 was translated.
# Text at index 2981 was translated.
# Text at index 2982 was translated.
# Text at index 2983 was translated.
# Text at index 2984 was translated.
# Text at index 2985 was translated.
# Text at index 2986 was translated.
# Text at index 2987 was translated.
# Text at index 2988 was translated.
# Text at index 2989 was translated.
# Text at index 2990 was translated.
# Text at index 2991 was translated.
# Text at index 2992 was translated.
# Text at index 2993 was translated.
# Text at index 2994 was translated.
# Text at index 2995 was translated.
# Text at index 2996 was translated.
# Text at index 2997 was translated.
# Text at index 2998 was translated.
# Text at index 2999 was translated.
# Text at index 3000 was translated.
# Text at index 3001 was translated.
# Text at index 3002 was translated.
# Text at index 3004 was translated.
# Text at index 3005 was translated.
# Text at index 3006 was translated.
# Text at index 3008 was translated.
# Text at index 3009 was translated.
# Text at index 3011 was translated.
# Text at index 3012 was translated.
# Text at index 3013 was translated.
# Text at index 3014 was translated.
# Text at index 3015 was translated.
# Text at index 3016 was translated.
# Text at index 3017 was translated.
# Text at index 3018 was translated.
# Text at index 3019 was translated.
# Text at index 3020 was translated.
# Text at index 3021 was translated.
# Text at index 3022 was translated.
# Text at index 3023 was translated.
# Text at index 3025 was translated.
# Text at index 3026 was translated.
# Text at index 3027 was translated.
# Text at index 3028 was translated.
# Text at index 3029 was translated.
# Text at index 3030 was translated.
# Text at index 3031 was translated.
# Text at index 3032 was translated.
# Text at index 3033 was translated.
# Text at index 3034 was translated.
# Text at index 3035 was translated.
# Text at index 3036 was translated.
# Text at index 3037 was translated.
# Text at index 3038 was translated.
# Text at index 3039 was translated.
# Text at index 3040 was translated.
# Text at index 3041 was translated.
# Text at index 3042 was translated.
# Text at index 3043 was translated.
# Text at index 3044 was translated.
# Text at index 3045 was translated.
# Text at index 3046 was translated.
# Text at index 3047 was translated.
# Text at index 3048 was translated.
# Text at index 3049 was translated.
# Text at index 3050 was translated.
# Text at index 3051 was translated.
# Text at index 3052 was translated.
# Text at index 3053 was translated.
# Text at index 3054 was translated.
# Text at index 3055 was translated.
# Text at index 3056 was translated.
# Text at index 3057 was translated.
# Text at index 3058 was translated.
# Text at index 3059 was translated.
# Text at index 3060 was translated.
# Text at index 3061 was translated.
# Text at index 3062 was translated.
# Text at index 3063 was translated.
# Text at index 3064 was translated.
# Text at index 3065 was translated.
# Text at index 3067 was translated.
# Text at index 3069 was translated.
# Text at index 3070 was translated.
# Text at index 3071 was translated.
# Text at index 3072 was translated.
# Text at index 3073 was translated.
# Text at index 3074 was translated.
# Text at index 3075 was translated.
# Text at index 3076 was translated.
# Text at index 3077 was translated.
# Text at index 3078 was translated.
# Text at index 3079 was translated.
# Text at index 3080 was translated.
# Text at index 3081 was translated.
# Text at index 3082 was translated.
# Text at index 3083 was translated.
# Text at index 3084 was translated.
# Text at index 3085 was translated.
# Text at index 3086 was translated.
# Text at index 3087 was translated.
# Text at index 3089 was translated.
# Text at index 3090 was translated.
# Text at index 3091 was translated.
# Text at index 3092 was translated.
# Text at index 3093 was translated.
# Text at index 3094 was translated.
# Text at index 3097 was translated.
# Text at index 3099 was translated.
# Text at index 3100 was translated.
# Text at index 3101 was translated.
# Text at index 3102 was translated.
# Text at index 3103 was translated.
# Text at index 3104 was translated.
# Text at index 3105 was translated.
# Text at index 3106 was translated.
# Text at index 3108 was translated.
# Text at index 3109 was translated.
# Text at index 3110 was translated.
# Text at index 3111 was translated.
# Text at index 3113 was translated.
# Text at index 3114 was translated.
# Text at index 3115 was translated.
# Text at index 3116 was translated.
# Text at index 3117 was translated.
# Text at index 3118 was translated.
# Text at index 3119 was translated.
# Text at index 3120 was translated.
# Text at index 3121 was translated.
# Text at index 3122 was translated.
# Text at index 3123 was translated.
# Text at index 3124 was translated.
# Text at index 3125 was translated.
# Text at index 3126 was translated.
# Text at index 3127 was translated.
# Text at index 3128 was translated.
# Text at index 3129 was translated.
# Text at index 3130 was translated.
# Text at index 3131 was translated.
# Text at index 3133 was translated.
# Text at index 3134 was translated.
# Text at index 3135 was translated.
# Text at index 3136 was translated.
# Text at index 3137 was translated.
# Text at index 3138 was translated.
# Text at index 3139 was translated.
# Text at index 3140 was translated.
# Text at index 3141 was translated.
# Text at index 3142 was translated.
# Text at index 3143 was translated.
# Text at index 3144 was translated.
# Text at index 3145 was translated.
# Text at index 3146 was translated.
# Text at index 3147 was translated.
# Text at index 3148 was translated.
# Text at index 3149 was translated.
# Text at index 3150 was translated.
# Text at index 3151 was translated.
# Text at index 3152 was translated.
# Text at index 3153 was translated.
# Text at index 3154 was translated.
# Text at index 3155 was translated.
# Text at index 3156 was translated.
# Text at index 3158 was translated.
# Text at index 3159 was translated.
# Text at index 3160 was translated.
# Text at index 3161 was translated.
# Text at index 3162 was translated.
# Text at index 3163 was translated.
# Text at index 3165 was translated.
# Text at index 3167 was translated.
# Text at index 3168 was translated.
# Text at index 3169 was translated.
# Text at index 3170 was translated.
# Text at index 3172 was translated.
# Text at index 3173 was translated.
# Text at index 3174 was translated.
# Text at index 3175 was translated.
# Text at index 3176 was translated.
# Text at index 3177 was translated.
# Text at index 3178 was translated.
# Text at index 3179 was translated.
# Text at index 3181 was translated.
# Text at index 3182 was translated.
# Text at index 3183 was translated.
# Text at index 3185 was translated.
# Text at index 3186 was translated.
# Text at index 3188 was translated.
# Text at index 3189 was translated.
# Text at index 3190 was translated.
# Text at index 3191 was translated.
# Text at index 3192 was translated.
# Text at index 3193 was translated.
# Text at index 3194 was translated.
# Text at index 3195 was translated.
# Text at index 3196 was translated.
# Text at index 3197 was translated.
# Text at index 3198 was translated.
# Text at index 3200 was translated.
# Text at index 3202 was translated.
# Text at index 3205 was translated.
# Text at index 3206 was translated.
# Text at index 3207 was translated.
# Text at index 3208 was translated.
# Text at index 3209 was translated.
# Text at index 3211 was translated.
# Text at index 3212 was translated.
# Text at index 3213 was translated.
# Text at index 3214 was translated.
# Text at index 3215 was translated.
# Text at index 3216 was translated.
# Text at index 3217 was translated.
# Text at index 3218 was translated.
# Text at index 3219 was translated.
# Text at index 3220 was translated.
# Text at index 3221 was translated.
# Text at index 3222 was translated.
# Text at index 3223 was translated.
# Text at index 3224 was translated.
# Text at index 3226 was translated.
# Text at index 3227 was translated.
# Text at index 3228 was translated.
# Text at index 3229 was translated.
# Text at index 3230 was translated.
# Text at index 3231 was translated.
# Text at index 3232 was translated.
# Text at index 3233 was translated.
# Text at index 3234 was translated.
# Text at index 3235 was translated.
# Text at index 3236 was translated.
# Text at index 3237 was translated.
# Text at index 3238 was translated.
# Text at index 3239 was translated.
# Text at index 3240 was translated.
# Text at index 3241 was translated.
# Text at index 3242 was translated.
# Text at index 3243 was translated.
# Text at index 3244 was translated.
# Text at index 3245 was translated.
# Text at index 3246 was translated.
# Text at index 3247 was translated.
# Text at index 3248 was translated.
# Text at index 3249 was translated.
# Text at index 3250 was translated.
# Text at index 3251 was translated.
# Text at index 3252 was translated.
# Text at index 3253 was translated.
# Text at index 3254 was translated.
# Text at index 3255 was translated.
# Text at index 3256 was translated.
# Text at index 3257 was translated.
# Text at index 3258 was translated.
# Text at index 3259 was translated.
# Text at index 3260 was translated.
# Text at index 3261 was translated.
# Text at index 3263 was translated.
# Text at index 3264 was translated.
# Text at index 3265 was translated.
# Text at index 3266 was translated.
# Text at index 3267 was translated.
# Text at index 3268 was translated.
# Text at index 3269 was translated.
# Text at index 3270 was translated.
# Text at index 3271 was translated.
# Text at index 3272 was translated.
# Text at index 3273 was translated.
# Text at index 3274 was translated.
# Text at index 3275 was translated.
# Text at index 3276 was translated.
# Text at index 3277 was translated.
# Text at index 3278 was translated.
# Text at index 3279 was translated.
# Text at index 3280 was translated.
# Text at index 3281 was translated.
# Text at index 3282 was translated.
# Text at index 3283 was translated.
# Text at index 3284 was translated.
# Text at index 3285 was translated.
# Text at index 3286 was translated.
# Text at index 3287 was translated.
# Text at index 3288 was translated.

# %%
#for testing result while or after translation
df.head()
# Out:
#           name  original_idx              website_url  \
# 0      itravel             0  https://www.itravel.de/
# 1      kunveno             2       https://kunveno.de
# 3       Scopas             4   https://www.scopas.io/
# 4  studymaniac             5   https://studymaniac.de
# 6       Aicone             9      http://www.ai-c.one
#
#                                         website_text original_language  \
# 0  itravel Telefonische Beratung +49 221 8282 888...                de
# 1  Kunveno - Work Happier WORK HAPPIER Booste Unt...                de
# 3  ScopasWe're working on something new.Check it ...                en
# 4  Studymaniac - erfolgreich Studieren Open main ...                de
# 6  Aicone - Artificial Intelligence Cloud One | A...                en
#
#                                   website_text_in_en
# 0  itravel Telefonische Beratung +49 221 8282 888...
# 1  Kunveno - Work Happier WORK HAPPIER Booste Unt...
# 3  ScopasWe're working on something new.Check it ...
# 4  Studymaniac - erfolgreich Studieren Open main ...
# 6  Aicone - Artificial Intelligence Cloud One | A...

# %%
#test result and store the result in another dataframe 
df_result_after_translation = df.copy()
df_result_after_translation
# Out:
#                    name  original_idx                 website_url  \
# 0               itravel             0     https://www.itravel.de/
# 1               kunveno             2          https://kunveno.de
# 3                Scopas             4      https://www.scopas.io/
# 4           studymaniac             5      https://studymaniac.de
# 6                Aicone             9         http://www.ai-c.one
# ...                 ...           ...                         ...
# 3284             Coleap          4994         https://coleap.com/
# 3285  Trade Machines FI          4995    http://trademachines.com
# 3286             Yasoon          4996          http://yasoon.com/
# 3287         Phoneboost          4997  https://www.phoneboost.de/
# 3288        Gaius Legal          4999      http://www.gaius.legal
#
#                                            website_text original_language  \
# 0     itravel Telefonische Beratung +49 221 8282 888...                de
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...                de
# 3     ScopasWe're working on something new.Check it ...                en
# 4     Studymaniac - erfolgreich Studieren Open main ...                de
# 6     Aicone - Artificial Intelligence Cloud One | A...                en
# ...                                                 ...               ...
# 3284  Coleap Transform your content into incomeTurn ...                en
# 3285  ▷ All used industrial equipment online on Trad...                en
# 3286  Home - yasoon Patrick Partner Manager Get in t...                en
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...                de
# 3288  Gaius - Dein Personal Legal Assistant Homepage...                de
#
#                                      website_text_in_en
# 0     itravel Telefonische Beratung +49 221 8282 888...
# 1     Kunveno - Work Happier WORK HAPPIER Booste Unt...
# 3     ScopasWe're working on something new.Check it ...
# 4     Studymaniac - erfolgreich Studieren Open main ...
# 6     Aicone - Artificial Intelligence Cloud One | A...
# ...                                                 ...
# 3284  Coleap Transform your content into incomeTurn ...
# 3285  ▷ All used industrial equipment online on Trad...
# 3286  Home - yasoon Patrick Partner Manager Get in t...
# 3287  Phoneboost – Boost up your phone! AKKU LEER?PH...
# 3288  Gaius - Dein Personal Legal Assistant Homepage...
#
# [3021 rows x 6 columns]

# %%
#load the result from steps before
df = df_result_after_translation.copy()
df

#store result as json-file
df.to_json('../../data/preprocessed/translated_results_en.json')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Preprocesssing Functions from the exercise

# %%
#load data from transalted json and switch the transalted-Content as 'website_text'
df = pd.read_json('translated_results.json')

# Drop the "translatedContent" column
df.drop("Content", axis=1, inplace=True)

# Rename the "Content_in_de" column to replace the dropped column
df.rename(columns={"Content_in_de": "Content"}, inplace=True)

# Display the modified DataFrame
print(df)
# Out:
#      original_language                                            Content
# 0                   en  ANKOMMEN | Ihre LieblingsmarkenHolen Sie sich ...
# 1                   de  Rückabwicklung - von Lebensversicherungen Wir ...
# 2                   de     Starke Versicherungen für deinen Lifestyle ...
# 3                   en  RESTUBE - the airbag for more freedom and safe...
# 4                   de  CureVac - Wir revolutionieren die mRNA für das...
# ...                ...                                                ...
# 3275                de                      LEMONSGATE                ...
# 3276                de  Safily   Überspringen Suchen Suche schließen Z...
# 3277                de  Startseite | ICO-LUX   Fraud Prevention Über u...
# 3278                en  Versus | Alles vergleichen KategorienSmartphon...
# 3279                de  Selfstorage München and deutschlandweit | Stor...
#
# [3258 rows x 2 columns]

# %%
# import packages
import re

# import pandas as pd
# import numpy as np

# import matplotlib.pyplot as plt
# import seaborn as sns

import nltk
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
nltk.download('stopwords')


from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import GaussianNB

# from skmultilearn.problem_transform import BinaryRelevance
# Out:
# [nltk_data] Downloading package stopwords to /Users/kathi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## <span style="color:green">To do: Determine a threshold to throw out other frequently occurring words </span>

# %%
# define functions

def cleanPunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]', r'', sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]', r' ', cleaned)
    cleaned = re.sub(r'[äÄ]', 'ä', cleaned)
    cleaned = re.sub(r'[öÖ]', 'ö', cleaned)
    cleaned = re.sub(r'[üÜ]', 'ü', cleaned)
    cleaned = cleaned.strip()
    return cleaned

def keepAlpha(sentence):
    alpha_sent = ""
    for word in sentence.split():
        alpha_word = re.sub('[^a-zA-ZäöüÄÖÜß]+', ' ', word, flags=re.UNICODE)
        alpha_sent += alpha_word
        alpha_sent += " "
    alpha_sent = alpha_sent.strip()
    return alpha_sent

def removeStopWords(sentence, stopwords):
    re_stop_words = re.compile(r"\b(" + "|".join(stop_words) + ")\\W", re.I)   
    return re_stop_words.sub(" ", sentence)

def stemming(sentence):
    stemSentence = ""
    for word in sentence.split():
        stem = stemmer.stem(word)
        stemSentence += stem
        stemSentence += " "
    stemSentence = stemSentence.strip()
    return stemSentence

# define stopwords
stop_words = set(stopwords.words(['german', 'english']))

# define stemmer
stemmer = SnowballStemmer('german')

df['website_text'] = df['website_text'].astype(str)
# apply functions
df['website_text'] = df['website_text'].str.lower()
df['website_text'] = df['website_text'].apply(cleanPunc)
df['website_text'] = df['website_text'].apply(keepAlpha)
df['website_text'] = df['website_text'].apply(removeStopWords, stopwords=stopwords)
df['website_text'] = df['website_text'].apply(stemming)

# %%
# check result
df.head(50)
# Out:
#    original_language                                            Content
# 0                 en  ankomm lieblingsmarkenhol appuns visionpartner...
# 1                 de  ruckabwickl lebensversicher hol doppelt leb re...
# 2                 de  stark versicher lifestyl held de hom produkt f...
# 3                 en  restub airbag freedom safety wat restub skip c...
# 4                 de  curevac revolutioni mrna leb mensch fuhrungste...
# 5                 en  hom open bank project inhalt spring produkt op...
# 6                 en  viamon gmbh hom de hom technologi servic konta...
# 7                 en  hivebuy unternehmensweit ord rechnung losung h...
# 8                 de  startseit greenflash start mission referenz pr...
# 9                 de  sit undergoing maintenanc doctorsgat wartungsm...
# 10                en  domain detailseit tut leid app funktioniert ri...
# 11                de  event mediathek event kontakt demo preis cod e...
# 12                de  quasol modern finanzstatist en quasol modern f...
# 13                de  commodis mehrwert unternehm kontakt flexibl be...
# 14                de  softwar e commerc logist fulfillment codept de...
# 15                de  microbify gmbh anaerob mikrobiologi regensburg...
# 16                de  kw elektr bootsmotor v niedervolt molabo produ...
# 17                nl                             startseit frauwertvoll
# 18                de  one data en de demo anfordernprodukt one data ...
# 19                de  myboshi diy zentral frisch handarbeitside schl...
# 20                de  cyberluch cyb sich person verstand inhalt wech...
# 21                en  dayoff tut leid dayoff funktioniert richtig ja...
# 22                de  sprachcoaching training echzeit x search hom p...
# 23                en  willkomm tvey select gift bald muttertag dah s...
# 24                de  paydirekt gmbh betreib zahlverfahr giropay ein...
# 25                en  kostenlos medikament pillenerinner mediteo app...
# 26                en  lebensmittel wenig minut geliefert flink berei...
# 27                de  buddy app erlebniszeit appyou need enabl javas...
# 28                en  vectoflow hom prob system softwar randd servic...
# 29                de  trust security skip content digital zertifikat...
# 30                en  ecofario inhalt spring technologi technologi e...
# 31                en  aufstieg ki fuhrend kopf ki verbind kunstlich ...
# 32                en  hom grandcentrix gmbh unternehm homeub unsblog...
# 33                en  odilia privat market inhalt spring odilia priv...
# 34                de  wasserfilt osmoseanlag wasserwerk inhalt sprin...
# 35                en  startseit medicalvalu startseit diagnostic pat...
# 36                de  qr cod schlusseln comydo inhalt spring comydo ...
# 37                en  deep learning preisgestalt aristanderai deutsc...
# 38                de  anwalt such find anwalt de hinweis javascript ...
# 39                en  arculus jungheinrich unternehm zukunft autonom...
# 40                de  finanzmining de echtzeit analytics finanzdat f...
# 41                en  wesustain softwar verantwortungsvoll unternehm...
# 42                de  aaron digital mitarbeit fur praxistelefon prax...
# 43                de  erstell person nachtlamp amorlight such menu w...
# 44                de  pbm personal business machin ag innovativ saas...
# 45                de  hom uma schwangerschaft wochenbett uma app tea...
# 46                en  websit derzeit gewartet fakescout wartungsmodu...
# 47                de  dorrwerk natur snack dorrwerk natur snack voll...
# 48                en  meetlist imm wann imm hauptmenu startseit pres...
# 49                de  bett mail media weit wordpress websit spring i...

# %%
# function for tokenization -> only use when vectorizer doesn't include tokenization (probably included)
#def tokenize(text):
#    tokens = re.split(r'\W+', text)

#    return tokens

# applying function to the column
#df['website_text'] = df['website_text'].apply(lambda x: tokenize(x))
#df

# %%
# Specifiy the path to the folder where you want to save the CSV file
folder_path = '../data/preprocessed'

# Specify the file name and full path for the CSV file
file = 'preprocessed_data.csv'
path = os.path.join(folder_path, file)

# Save the preprocessed data to a CSV file
df.to_csv(path, index=False)

# %%
# generate requirements.txt without some weird paths instead of the package version
# !pip list --format=freeze > requirements_preprocessing.txt
